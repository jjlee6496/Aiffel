# %% [markdown]
# # 크롤링

# %%
# 크롤러를 만들기 전 필요한 도구들을 임포트합니다.
import requests
import pandas as pd
from bs4 import BeautifulSoup

# 페이지 수, 카테고리, 날짜를 입력값으로 받습니다.
def make_urllist(page_num, code1, code2, date): 
  urllist= []
  for i in range(1, page_num + 1):
    url = 'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm'+'&sid2='+str(code2)+'&sid1='+str(code1)+'&date='+str(date)+'&page='+str(i)
    headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.90 Safari/537.36'}
    news = requests.get(url, headers=headers)

    # BeautifulSoup의 인스턴스 생성합니다. 파서는 html.parser를 사용합니다.
    soup = BeautifulSoup(news.content, 'html.parser')

    # CASE 1
    news_list = soup.select('.newsflash_body .type06_headline li dl')
    # CASE 2
    news_list.extend(soup.select('.newsflash_body .type06 li dl'))
        
    # 각 뉴스로부터 a 태그인 <a href ='주소'> 에서 '주소'만을 가져옵니다.
    for line in news_list:
        urllist.append(line.a.get('href'))
  return urllist

# %%
from datetime import datetime
datetime.today().strftime("%Y%m%d")

url_list = make_urllist(2, 105, 283, datetime.today().strftime("%Y%m%d"))
print('뉴스 기사의 개수: ',len(url_list))
url_list[:5]
# Out:
# 뉴스 기사의 개수:  27
# ['https://n.news.naver.com/mnews/article/138/0002145590?sid=105',
#  'https://n.news.naver.com/mnews/article/138/0002145589?sid=105',
#  'https://n.news.naver.com/mnews/article/014/0004990825?sid=105',
#  'https://n.news.naver.com/mnews/article/092/0002287443?sid=105',
#  'https://n.news.naver.com/mnews/article/031/0000738317?sid=105']

# %%
idx2word = {'101' : '경제', '102' : '사회', '103' : '생활/문화', '105' : 'IT/과학'}
idx2word2 = {'731' : '모바일', '226' : '인터넷/SNS', '227' : '통신/뉴미디어', '230' : 'IT 일반', '732' : '보안/해킹', '283' : '컴퓨터'}

# %%
from newspaper import Article

#- 데이터프레임을 생성하는 함수입니다.
def make_data(urllist, code1, code2):
  text_list = []
  for url in urllist:
    article = Article(url, language='ko')
    article.download()
    article.parse()
    text_list.append(article.text)

  #- 데이터프레임의 'news' 키 아래 파싱한 텍스트를 밸류로 붙여줍니다.
  df = pd.DataFrame({'news': text_list})

  #- 데이터프레임의 'code' 키 아래 한글 카테고리명을 붙여줍니다.
  df['code1'] = idx2word[str(code1)]
  df['code2'] = idx2word2[str(code2)]
  return df

# %%
data = make_data(url_list, 105, 283)
#- 상위 10개만 출력해봅니다.
data[:10]
# Out:
#                                                 news  code1 code2
# 0  \n\n\n\n웹케시그룹은 이번 공채를 통해 ▲SW개발 ▲UI/UX디자인 ▲상품 ▲...  IT/과학   컴퓨터
# 1  [디지털데일리 이종현기자] 작년은 클라우드 업계에서 기념비적인 해라고 할 만합니다....  IT/과학   컴퓨터
# 2  [파이낸셜뉴스] NHN클라우드가 독립법인 출범 1주년을 맞이했다. 지난해 성과에 힘...  IT/과학   컴퓨터
# 3  시놀로지가 영상 보안 시스템 정보 유출을 막을 수 있는 가이드라인을 공개했다. (사...  IT/과학   컴퓨터
# 4  인공지능(AI) 스타트업 업스테이지는 카카오톡 아숙업(AskUp)에 이미지 생성 A...  IT/과학   컴퓨터
# 5  \n\n\n\n시프티는 올해 창업 5년차 기업으로 동명의 인력관리 솔루션 ‘시프티’...  IT/과학   컴퓨터
# 6  삼성SDS는 국내 최초로 '소프트웨어(SW) 프로세스 품질인증(SP인증)' 최고등급...  IT/과학   컴퓨터
# 7  웹 환경의 발전으로 대부분의 IT 서비스 시스템이 확장성, 유연성, 독립성을 제공하...  IT/과학   컴퓨터
# 8  토스플레이스는 애플페이 결제를 지원하기 위해 국제 결제 표준 규격인 EMV 컨택트리...  IT/과학   컴퓨터
# 9  \n\n\n\nKG스틸은 이번 프로젝트로 기존 ERP 시스템인 ‘SAP ECC 6....  IT/과학   컴퓨터

# %%
code_list = [[102,250], [103,243], [105,283]]
idx2word2 = {'731' : '모바일', '226' : '인터넷/SNS', '227' : '통신/뉴미디어', '230' : 'IT 일반', '732' : '보안/해킹', '283' : '컴퓨터', '250' : '교육', '243' : '책'}

code_list
# Out:
# [[102, 250], [103, 243], [105, 283]]

# %%
from multiprocessing import Pool
import random
import time, os

def make_total_data(page_num, code_list, date):
  start = int(time.time())  
  num_cores = 4  
  df = None
  for code1, code2 in code_list:
    pool = Pool(num_cores)
    url_list = make_urllist(page_num, code1, code2, date)
    df_temp = make_data(url_list, code1, code2)
    print(str(code1)+'번:'+str(code2)+'번'+' 코드에 대한 데이터를 만들었습니다.')
    pool.close()
    pool.join()
    time.sleep(random.randint(0,1))
    if df is not None:
      df = pd.concat([df, df_temp])
    else:
      df = df_temp

  print("***run time(sec) :", int(time.time()) - start)
  return df

# %%
df = make_total_data(1, code_list, datetime.today().strftime("%Y%m%d"))
# Out:
# 102번:250번 코드에 대한 데이터를 만들었습니다.
# 103번:243번 코드에 대한 데이터를 만들었습니다.
# 105번:283번 코드에 대한 데이터를 만들었습니다.
# ***run time(sec) : 25

# %%
import os

# 데이터프레임 파일을 csv 파일로 저장합니다.
# 저장경로는 이번 프로젝트를 위해 만든 폴더로 지정해 주세요.
csv_path = os.path.join(os.getcwd(), '/news')
df.to_csv(csv_path+'/news.csv', index=False)

if os.path.exists(csv_path):
  print('{} File Saved!'.format(csv_path))
# Out:
# c:/news File Saved!

# %%
import pandas as pd
csv_path = os.path.join(os.getcwd(), '/news')
df = pd.read_table(csv_path+'/news.csv', sep=',')
# 정규 표현식을 이용해서 한글 외의 문자는 전부 제거합니다.
df['news'] = df['news'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]", "", regex=True)
df.drop_duplicates(subset=['news'], inplace=True)

print('뉴스 기사의 개수: ',len(df))
# Out:
# 뉴스 기사의 개수:  58

# %%
from konlpy.tag import Mecab
tokenizer = Mecab(dicpath=r"C:\mecab\mecab-ko-dic")
kor_text = '밤에 귀가하던 여성에게 범죄를 시도한 대 남성이 구속됐다서울 제주경찰서는 \
            상해 혐의로 씨를 구속해 수사하고 있다고 일 밝혔다씨는 지난달 일 피해 여성을 \
            인근 지하철 역에서부터 따라가 폭행을 시도하려다가 도망간 혐의를 받는다피해 \
            여성이 저항하자 놀란 씨는 도망갔으며 신고를 받고 주변을 수색하던 경찰에 \
            체포됐다피해 여성은 이 과정에서 경미한 부상을 입은 것으로 전해졌다'

#- 형태소 분석, 즉 토큰화(tokenization)를 합니다.
print(tokenizer.morphs(kor_text))
# Out:
# ['밤', '에', '귀가', '하', '던', '여성', '에게', '범죄', '를', '시도', '한', '대', '남성', '이', '구속', '됐', '다', '서울', '제주', '경찰서', '는', '상해', '혐의', '로', '씨', '를', '구속', '해', '수사', '하', '고', '있', '다고', '일', '밝혔', '다', '씨', '는', '지난달', '일', '피해', '여성', '을', '인근', '지하철', '역', '에서부터', '따라가', '폭행', '을', '시도', '하', '려다가', '도망간', '혐의', '를', '받', '는다', '피해', '여성', '이', '저항', '하', '자', '놀란', '씨', '는', '도망갔으며', '신고', '를', '받', '고', '주변', '을', '수색', '하', '던', '경찰', '에', '체포', '됐', '다', '피해', '여성', '은', '이', '과정', '에서', '경미', '한', '부상', '을', '입', '은', '것', '으로', '전해졌', '다']

# %%
song = '''식사는 없어 배고파도
음료는 없어 목말라도
달콤한 맛만 디저트만 만 원하게 될 거 알잖아
식사는 없어 배고파도
음료는 없어 목말라도
달콤한 맛만 디저트만 만 원하게 될 거 알잖아
내가 만든 쿠키'''

# %%
tokenizer.morphs(song)
# Out:
# ['식사',
#  '는',
#  '없',
#  '어',
#  '배고파도',
#  '음료',
#  '는',
#  '없',
#  '어',
#  '목말',
#  '라도',
#  '달콤',
#  '한',
#  '맛',
#  '만',
#  '디저트',
#  '만',
#  '만',
#  '원',
#  '하',
#  '게',
#  '될',
#  '거',
#  '알',
#  '잖아',
#  '식사',
#  '는',
#  '없',
#  '어',
#  '배고파도',
#  '음료',
#  '는',
#  '없',
#  '어',
#  '목말',
#  '라도',
#  '달콤',
#  '한',
#  '맛',
#  '만',
#  '디저트',
#  '만',
#  '만',
#  '원',
#  '하',
#  '게',
#  '될',
#  '거',
#  '알',
#  '잖아',
#  '내',
#  '가',
#  '만든',
#  '쿠키']

# %%
stopwords = ['에','는','은','을','했','에게','있','이','의','하','한','다','과','때문','할','수','무단','따른','및','금지','전재','경향신문','기자','는데','가','등','들','파이낸셜','저작','등','뉴스']

# %%
# 토큰화 및 토큰화 과정에서 불용어를 제거하는 함수입니다.
def preprocessing(data):
  text_data = []

  for sentence in data:
    temp_data = []
    #- 토큰화
    temp_data = tokenizer.morphs(sentence) 
    #- 불용어 제거
    temp_data = [word for word in temp_data if not word in stopwords] 
    text_data.append(temp_data)

  text_data = list(map(' '.join, text_data))
  return text_data

# %%
text_data = preprocessing(df['news'])
text_data
# Out:
# ['기사 내용 요약 승마 체험 비 만 원 중 인 만 원 지원 거제 뉴시스 신정철 경남 거제시 말 산업 육성 승마 인구 저변 확대 를 위해 관내 초중 고등학교 재학 생 대상 으로 학생 승마 체험 지원 사업 추진 한다고 일 밝혔 학생 승마 체험 지원 사업 매년 월 부터 월 까지 실시 며 승마 체험 비 만 원 중 인 만 원 지원 한다 올해 억 만 원 자부담 포함 투입 해 명 대상 으로 지원 한다 희망자 중 대상자 로 확정 된 학생 동부면 소재 다솔 승마 장 에서 주말 토일 오전 시 부터 오후 시 까지 안전교육 승마 이론 교육 말타기 으로 이루어진 체험 학생 당 회회 당 분 걸쳐 진행 한다 거 제시 관계자 학생 승마 체험 통해 말 같 큰 동물 교감 함 으로써 정서 적 안정 바른 체형 교정 여 건강 몸 단련 데 도움 되 기 를 바란다고 말',
#  '전북 임충식 전라북도 교육청 교육감 서거석 학생 적성 흥미 맞 맞춤 형 진로 진학 상담 제공 위해 권역 별 대면 진학 상담 운영 한다고 일 밝혔 대상 전라북도 소재 고등학교 학생 졸업 생 검정고시 생 학부모 다상담 오 일 부터 월 까지 요일 별 로 도 교육청 각 교육 지원 청 에서 이뤄진 시간 평일 오후 시분 부터 시분 까지 인 당 상담 시간 분 신청 시간 분 전 상담 장소 방문 등록 후 상담 진행 면 된 다상담 년 이상 진학 지도 경험 전북 대 입진 학지 도 지원 단 진학 상담 팀 교사 맡 게 된다 진학 상담 참여 고 싶 학생 학부모 전북 진로 진학 센터 홈 페이 접속 해 대입 대면 상담 신청 배 너 를 클릭 고 상담 원하 장소 와 시간 확인 후 접수증 출력 면 신청 마무리 된 다상담 신청 일 오후 시 부터 가능 며 상담 희망 일 주일 전 까지 만 신청 면 희망 일 상담 받 기타 자세 신청 방법 이나 운영 일 전북 진로 진학 센터 홈페이지 에서 확인 가능 유효선 학교 교육 과장 학교 에서 진로 진학 상담 이뤄지고 지만 더 많 정보 필요 학생 학부모 를 위해 권역 별 진학 상담 마련 다면서 우리 교육청 학생 학부모 진학 정보 공백 느끼 지 않 도록 다양 경로 를 통해 진학 정보 를 제공 도록 최선 겠 다고 말',
#  '세종 서한샘 교육부 오 일 열리 국회 교육 위원회 청문회 이후 학교 폭 력학 폭 근절 대책 공식 발표 한다고 일 밝혔 다만 오 일 학 폭 대책 관련 으로 당정 협의회 열릴 예정 어서 이때 대책 상당 부분 공개 될 것 으로 예상 된다 김천홍 교육부 대변인 이날 정부세종청사 에서 열린 정례 브리핑 에서 청문회 연기 됨 따라 일정 조율 불가피 게 됐 다며 같이 밝혔 당초 학 폭 근절 대책 지난달 일 국회 교육 위원회 청문회 를 거쳐 월 첫째 주 학 폭 대책 위원회 에서 발표 될 예정 었 그러나 정순신 변호사 불참 이유 로 국회 청문회 일 로 미뤄 지 면서 교육부 학 폭 근절 대책 발표 일정 다시 조율 고 김 대변인 구체 적 인 날짜 말 없 지만 현재 로서 청문회 이후 최종 적 으로 발표 일정 조율 고 다고 말 다만 일 오전 중 당정 협의회 예정 돼 어 학 폭 근절 대책 상당 내용 이때 공개 될 것 으로 보인다 이날 당정 협의회 이주호 부총리 겸 교육부 장관 참석 예정 김 대변인 당정 협의회 에서 기본 적 으로 방향 주요 내용 협의 고 여당 에서 결과 를 브리핑 것 으로 알 고 다며 이때 내용 상당 부분 알려질 것 으로 예상 고 다고 말',
#  '모두 보여 주 고 싶 기사 라면 기사 를 추천 합니다 버튼 눌러 주 세요 집계 기간 동안 추천 많이 받 기사 네이버 자동 기사 배열 영역 추천 요소 로 활용 됩니다 레이어 닫 기',
#  '기사 내용 요약 일 부터 성적표 출력 학습 계획 수립 본격 화 교육 업계 기출 문제집 으로 학생 학부모 공략 서울 뉴시스 배 민욱 올해 첫 전국연합 학력 평가 학평 로 그간 학습 성과 를 중간 점검 수험 생 향후 예정 된 모의고사 와 대학 수학 능력 시험 수능 대비 해 본격 적 인 학습 전략 세우 기 돌입 첫 전국 단위 모의고사 였 던 만큼 월 학평 으로 본인 위치 를 파악 고 취약점 보완 계기 로 삼 아야 한다는 입시 전문가 조언 이어지 고 교육 업계 도 과목 별 기본기 강화 취약 과목 보완 초점 둔 맞춤 형 학습 교재 로 학생 학부모 마음 잡 기 나섰 일 관련 업계 따르 면 수험 생 지난달 일 치러진 학평 가채점 기준 으로 정시 지원 가능 대학 군 체크 고 취약 과목 대한 보완 계획 수립 집중 고 특히 학평 성적표 출력 가능 해 지 일 부터 학습 전략 수립 본격 화 될 전망 학평 성적표 원 점수 와 등급 표준 점수 영역 별 배점 득점 전국 평균 모두 확인 좀 더 세부 적 인 학습 계획 마련 데 큰 도움 된다고 수험 생 월 학평 기점 으로 본격 적 인 대입 학습 계획 수립 돌입 면서 교육 업계 맞춤 형 학습 교재 를 강조 고 천재교육 수능 대비 를 위한 고등 국어 문제집 명 강사 인 지혜 를 출시 대학 교수 현직 교사 유명 학원 강사 교과서 집필진 국어 전문가 명 개발 참여 인 지혜 문학 편 문법 화 작편 독 서편 권 으로 구성 됐 국어 영역 공통 과목 인 문학 독서 물론 선택 과목 인 화법 작문 언어 와 매체 까지 모두 대비 가능 특히 인 지혜 국어 전문가 수능 각종 모의고사 기출문제 를 분석 해 수능 내신 두루 적용 되 핵심 개념 정리 해 다양 예시 와 함께 쉽 고 자세 게 풀어냈 출제 유형 개념 활용 해 지문 읽 팁 다양 학습 노하우 도 추가 로 제공 고 교육 출판 업체 미래엔 최근 학년도 수능 대비 기출 문제집 기출 국어 영어 시리즈 를 새롭 게 출간 기출 최신 출제 경향 반영 해 최근 년 간 수능 평가 원 기출문제 수록 수능 대비 기출 문제집 전 과목 자기 주도 학습 가능 도록 코드 를 통해 디지털 스터디 플래너 와 과목 별 오답 노트 를 무료 로 제공 한다 입시 국어 교육 콘텐츠 기업 이감 국어 교육 연구소 감 이감 으로 기출 독서 기 독 를 지난해 말 출간 학년도 수능 대비 문제집 인 기독 최신 년 평가 원 기출 수록 수험 생 출제 자 시각 에서 어떤 것 읽 어 내 야 는지 를 분석 며 훈련 교재 다키 출판사 매국 어 시리즈 매비 매문 예비 매비 예비 매문 으로 돼 년 넘 게 출간 된 장수 참고서 어휘력 독해력 향상 시킬 공부 법 제안 한다 김덕유 천재 교육 중 개발 본부 이사 수험 생 월 학평 이후 로 자신 희망 대학 현재 지원 가능 대학 비교 면서 한층 목표 지향 적 인 학습 계획 수립 고 다며 개인 학업 수준 이나 목표 따라 적합 교재 를 선택 것 도 대입 학습 계획 수립 중요 요소 인 만큼 교육 기업 전략 적 마케팅 도 활발 해 지 고 다고 말',
#  '광주시 교육청 제공 재판매 광주시 교육청 제공 재판매 광주 연합뉴스 김재선 광주시 교육청 관내 고등학생 대상 학년도 학기 학교 간 공동 교육 과정 개강 일 시 교육청 따르 면 학기 학교 간 공동 교육 과정 개 강좌 개설 돼 여개 학교 에서 총 천 여 명 학생 참여 한다 온라인 공동 교육 과정 개 강좌 실시간 쌍방향 수업 으로 오프라인 공동 교육 과정 개 강좌 대 면 수업 으로 진행 된다 학교 간 공동 교육 과정 수강 희망 학생 적 거나 가르칠 교사 부족 으로 단위 학교 에서 개설 어려운 과목 학교 간 연계 협력 통해 운영 정규 교육 과정 온라인 과정 정규 일 시간 내 대면 수업 과정 방과 후 시간 이나 주말 수업 이뤄진 다시 교육청 다양 과목 개설 위해 광주 교대 서영대 조선대 조선 간 호대 광주 시청자 미디어 센터 협력 해 해당 과목 전문 성 높였 화학 실험 창 경영 연극 제작 실습 영상 제작 이해 교육학 기초 간호 임상 실무 동아시아 사 스페인어 프랑스어 다양 강좌 를 개설 김 선성 중 특수 교육 과장 공동 교육 과정 운영 으로 학생 학업 부담 줄어들 고 과목 선택 권 더욱 다양 게 보장 것 으로 기대 한다고 밝혔',
#  '한국과학기술원 제공 재판매 한국과학기술원 제공 재판매 한국과학기술원 제공 재판매 한국과학기술원 제공 재판매 왼쪽 부터 최민기 생명 화학 공학 교수 와 김채훈 응용과학 연구소 박사 한국과학기술원 제공 재판매 왼쪽 부터 최민기 생명 화학 공학 교수 와 김채훈 응용과학 연구소 박사 한국과학기술원 제공 재판매 대전 연합뉴스 정윤 덕 국내 연구 진이 화학 제약 산업 필수 인 고순 도 유기 용매 를 친환경 적 으로 분리 신 기술 개발 한국과학기술원 생명 화학 공학 최민기 교수 연구 팀 차원 다공성 탄소 기반 유기 용매 정제 용 초고 성능 나노 여과 막 개발 다고 일 밝혔 유기 용매 를 분리 기 위해서 혼합물 이루 물질 간 끓는점 차이 를 이용 해 분리 증류 법 사용 되 고 대용량 혼합물 끓여야 만큼 막대 에너지 와 비용 소모 되 고 가열 과정 에서 고부 가치 생성물 화학 적 변성 위험 배제 없 었 같 단점 극복 기 위해 단순히 압력 가하 것 만 으로 유기 용매 를 높 효율 로 분리 분리 막 기술 대한 요구 꾸준히 증가 고 연구 팀 나노미터 억분 이하 작 기공 갖 제올라이트 내부 탄소 를 채워 넣 후 제올라이트 만 선택 적 으로 녹여 냄 으로써 판 형태 차원 탄소 물질 합성 데 성공 이어 극도 로 균일 크기 마이크 로 기공 벌집 구조 로 빽빽 게 배열 된 차원 탄소 시트 적층 시켜 얇 두께 분리 막 제조 분리 막 유기 용매 나노 여과 적용 결과 탄소 시트 기공 보다 큰 용질 효과 적 으로 걸러 냄 으로써 고 순도 유기 용매 를 얻 었 특히 높 기공 밀도 덕분 기존 분리 막 보다 비약 적 으로 높 유기 용매 투과도 를 보여 유기 용매 대량 정제 도 매우 적합 다고 연구 팀 설명 최민기 교수 극도 로 균일 크기 마이크 로 기공 초고 밀도 로 존재 차원 다공성 탄소 합성 방법 세계 적 으로 보 고 된 바 없 던 새로운 개념 라며 이번 연구 에서 개발 탄소 물질 분리 막 뿐 만 아니 라 배터리 나 축전지 같 전기 화학 적 에너지 저장 장치 화학 적 센서 다양 분야 에서 활용 가능 것 으로 기대 한다고 말 응용과학 연구소 김채훈 박사 제 저자 로 참여 이번 연구 성과 세계 적 권위지 인 사이언스 어 드 밴 시스 지난 월 일 게재 됐',
#  '경기도 교육청 사립 고등학교 특수 학교 개교 억 원 지원 해 교육 환경 개선 한다고 일 밝혔 앞서 경기도 교육청 사립 고등학교 특수 학교 개교 로부터 교육 환경 개선 지원 신청 받 아 개 교육 지원 청 현장 점검 실무 협의회 평가 거쳐 도 교육청 계약 위반 으로 제재 대상 인 개교 를 제외 나머지 학교 를 지원 대상 으로 선정 지원 대상 학교 경기도 교육청 예산 받 아 교실 교체 냉난 방기 교체 창호 교체 외벽 개선 화장실 환경 개선 옥상 방수 개 교육 환경 개선 사업 진행 한다 경기도 교육청 매년 억 원 예산 투입 해 사립 학교 교육 환경 개선 사업 고 지난해 억 원 올해 억 원 편성 경기도 교육청 관계자 올해 편성 된 예산 중 남 부분 하반기 차 지원 통해 사용 예정 라며 사립 학교 다양 의견 수렴 해 학생 만족 교육 환경 조성 도록 노력 겠 다고 말',
#  '대구시 교육청 한복 아름다움 알리 기 위해 년 개 나라 개 해외 학교 학생 벌 한복 보냈 다고 밝혔 습니다 촬영 사진 공모 사진 전 도 열 어 투표 를 통해 우수 작 선정 해 시상 계획 입니다 년 학생 학부모 교직원 대상 으로 해외 한복 나눠 주 사업 시작 고 년 부터 아름다운 가게 대구경북 본부 와 함께 참가 범위 를 모든 시민 으로 확대 해 진행 고 습니다 또 해외 학생 한복 입 고 현지 에서 대구시 교육청',
#  '인하 대학교 최근 지역 스포츠 문화 저변 확대 를 위한 제회 인하 대학교 총장 배 인천 유소년 축구 대회 를 다고 일 밝혔 이번 대회 지난 일 인하 대 주 최 인천 유나이티 드 아카데미 미추홀 지부 주관 으로 인하 대 대 운동장 에서 열렸 년 첫 대회 개최 이후 코로나 팬데 믹 으로 잠정 연기 된 지 년 만 대회 에서 유치 부 부터 초등 부 까지 인천 각지 에서 모인 총 개 팀 실력 겨뤘 치열 승부 끝 유치 부 에선 팀 학년 부 에서 프리즘 학년 부 에서 프리즘 학년 부 에서 부천 유나이티 드 학년 부 에서 두나 미스 학년 부 에서 인천 유나이티 드 아카데미 미추홀 학년 부 에서 각각 우승 우승 팀 비롯 참가 학생 김웅희 인하 대 대외 부총장 박현순 인하 대 대외 협력 처장 신충식 인천시 의회 교육 위원장 으로부터 응원 격려 를 받 았 인하 대는 인천 스포츠 문화 를 활성 화 고자 대회 를 열 기 시작 지역 에서 성장 학생 자연 스럽 게 스포츠 를 즐길 분위기 를 만드 것 대회 목표 다인 대는 앞 으로 도 지역 스포츠 문화 확산 스포츠 인재 양성 힘 보탤 계획 다조 명우 인하 대 총장 우리 나라 스포츠 더욱 성장 기 위해선 지역 에서 자라나 학생 스포츠 흥미 를 느끼 고 즐기 게 무엇 보다 중요 다며 학생 쉽 게 스포츠 를 접하 고 건전 경쟁 통해 한층 더 성장 다양 행사 와 대회 지역 에서 열리 도록 힘쓰 겠 다고 말',
#  '경기 대학교 년 도 소프트웨어 테스트 전문가 자격 시험 학부 생 명 합격 해 대학 기관 중 에서 최다 합격자 를 배출 였 다고 일 밝혔 다는 국가 공인 자격 시험 으로 소프트웨어 품질 테스트 프로세스 테스트 케이스 설계 테스트 실행 역량 평가 국내 최고 품질 자격 으로 알려져 이번 자격 시험 에서 경기 대 높 합격률 응시 자 명 중 에서 이정우 컴 공 군 차석 합격 컴퓨터 공학 비롯 해 경제학 산업 시스템 공학 외식 조리 학과 로 합격 생 분포 확대 자격 취득자 명년 명년 명년 지속 증가 성과 를 냈 시험 주관 한국 정보 통신 기술 협회 아카데미 김재웅 단장 현업 실무자 대거 응시 시험 에서 합격률 보다 높 합격률 보이 며 차석 합격자 까지 배출 경기 대 결과 놀랍 다고 말 다경 기대 정부 소프트웨어 중심 대학 사업 수행 으로 소프트웨어 검증 과목 신설 산업체 와 공동 강의 한국 정보 통신 기술 협회 와 협력 테스트 전문가 양성 교육 스크럼 프로세스 교육 다양 교과 비교 프로그램 운영 고 권기현 소프트웨어 중심 대학 사업 단장 자격 취득 학생 실무 경험 높이 기 위해 산업체 인턴 십 확대 것 며 소프트웨어 테스트 뿐 만 아니 라 소프트웨어 안전 사이버 보안 인재 를 양성 여 국가 안전 산업 기여 고자 한다고 소감 밝혔',
#  '대구시 교육청 외국 학생 한복 아름다움 홍보 고 포스트 코로나 시대 국제 교류 를 활성 화 고자 글로벌 한복 나눔 사업 추진 한다고 일 밝혔 글로벌 한복 나눔 시 교육청 지난 년 부터 추진 해 온 사업 으로 그간 총 개국 천 벌 한복 보내왔 를 통해 해외 학생 한복 아름다움 알리 고 중국 신 동북공정 대응 해 우리 문화 를 알리 기 위해 힘써왔 다년 부터 아름다운 가게 대구경북 본부 와 업무 협약 맺 고 참가 범위 를 학생 학부모 교직원 에서 시민 까지 확대 했으며 를 통해 올해 모두 벌 한복 기증 받 아 북 남미 유럽 호주 뉴질랜드 개국 개 해외 학교 한국어 반 학생 보냈 와 함께 한국 문화 국제 적 위상 드높이 고 글로벌 소통 역량 강화 기 위해 해외 학생 한복 입 고 현지 명소 에서 촬영 사진 공모 글로벌 한복 사진 공모전 열 어 국내 학생 학부모 시민 뿐 만 아니 라 해외 학교 학생 참여 투표 를 통해 우수 작 선정 예정 강은희 대구시 교육감 우리 아름다운 한복 해외 학생 나눔 으로써 우리 문화 를 해외 널리 알리 고 함께 교류 좋 계기 되 기 를 바란다 며 포스트 코로나 시대 맞 다양 국제 교류 프로그램 확대 해 우리 학생 세계 시민 역량 기를 도록 지원 아끼 지 않 겠 다고 말',
수업 학급 운영 적용 교사 지도 매뉴얼 로 활용 도록 제작 됐 구체 적 으로 통합교육 관련 업무 통합교육 이해 모두 를 위한 통합교육 이상 변호사 우영 우 마주 기 꼬리 꼬리 를 무 신박 특수 교육 사전 으로 구성 됐 또 발달 장애 교육 지원 긍정 적 행동 지원 통합 교사 마음가짐 통합 학급 교사 용 자 점검 목록 장애 유형 별 지도 방법 에듀 테크 기반 미래형 특수 교육 현장 기반 통합교육 위한 실질 적 내용 담겨 도 교육청 모두 꽃 야 문구 의미 서로 다른 개성 인정 다양 성 관점 으로 모두 존중 받 공존 통합교육 전북 학생 중심 미래 교육 모습 표현 다고 설명 수첩 제작 초중 통합 학급 일반 학급 교사 와 특수 교사 전주 예술 중 재학 생 학교 구성원 기획 단계 에서부터 원고 손 그림 직접 참여 서거석 교육감 도 하드커버 표지 모두 꽃 야 서체 를 직접 작성 수첩 제작 큰 관심 쏟 았 다서 교육감 격려사 를 통해 통합교육 현장 에서 아이 지도 선생 님 께 도움 드리 고자 모두 꽃 야 를 준비 다면서 학생 개개인 다양 성 저마다 탁월 함 으로 천 개 꽃 천 개 꿈 이루어지 더불 어 미래 를 여 통합교육 활짝 열리 길 바란다고 말',
#  '대구시 교육청 올해 예산 억 천만 원 투입 해 초등 학교 학년 학생 만 천 여 명 대상 으로 수영 실기 교육 실시 한다 코로나 로 인해 지난 년 간 동영상 콘텐츠 워크 북 이론 교육 자료 와 가상현실 기기 를 활용 수영 이론 교육 운영 돼왔 그러 방역 지침 점차 완화 되 면서 지난해 학기 초등 학교 학년 만 대상 으로 수영 실기 교육 이뤄졌 일상 회복 맞 올해 참여 대상 확대 해 초등 학교 학년 학년 학생 대상 으로 교육 과정 내 생존 기능 수영 기능 구조 기능 포함 실기 교육 시간 편성 해 수영 실기 교육 실시 예정 올해 초등 수영 실기 교육 물 대한 적 응 연습 발차기 구명조끼 착용 법 주변 물품 이용 부유물 킥 판 바지 병 로 뜨 기 장비 구조법 자기 구조 법물 빠지 더라도 물 밖 으로 고개 를 내밀 고 숨 쉴 법 보빙 숨 쉬 기 위해 위아래 로 올라오 고 내려가 것 반복 며 잠수 것 배영 평영 영법 익히 기 다양 프로그램 으로 구성 됐 학생 각자 수준 맞 게 위기 상황 에서 생존 능력 키울 것 으로 기대 된다 또한 수영 실기 교육 필요 각급 학교 교육 일정 조정 수영장 배정 차량 임차 행정 업무 를 시 교육청 맡 아 추진 함 으로써 학교 현장 업무 를 최소 화 방침 강은희 대구시 교육감 올해 학교 교육 활동 정상 화 되 고 모든 일상 생활 회복 돼 학생 안전 도 각별 주의 요구 된다며 우리 학생 물 대한 적응력 위기 대처 요령 익혀 수상 안전사고 발생 시 소중 생명 지킬 능력 키울 도록 다양 지원 해 나가 겠 다고 말',
이유 무엇 일까 그 해답 찾아가 여정 에서 독자 따뜻 함 라는 감정선 만나 게 된다 책 추 천사 를 쓴 최재천 교수 아직 도 성악설 성선설 사이 에서 흔들리 당신 책 권한 정연 논리 로 처럼 마음 따뜻 게 해 주 책 참 오랜만 라고 말 기 도 책 에서 자기 가축 화 라는 개념 언급 며 친화력 자기 가축화 를 통해서 진화 다고 주장 한다 가축화 연구 를 통해 우리 종 초 강력 인지 능력 어떻게 진화 는지 이해 었 고 자기 가축화 가설 우리 와 다른 사람 인간 이하 로 취급 우리 종 경향 극복 해법 으로서 강력 도구 라고 말 한다 자기 가축화 연구 를 통해 친화력 동물 인지 능력 특히 협력 의사소통 측면 에서 더 유리 게 작용 다는 근거 하나 둘 쌓이 고 음 밝혔 심리학 에서 말 마음 이론 즉 타인 마음 읽 능력 정교 방식 으로 타인 협력 며 의사소통 게 해준다 동물 의사소통 어서 도 마음 이론 적용 된다 동물 사람 사람 사람 사이 모두 눈 마주치 고 다정 목소리 를 낼 때 더 주의 를 집중 게 된다고 한다 동작 목소리 를 통해 선의 인지 악의 인지 파악 것 사람 마음 읽 고 추론 능력 협력 적 의사소통 으로 까지 이어질 다는 것 또한 타인 알아보 기 시작 며 서 마음 이론 능력 활성 화 되 것 마음 이론 에서 발생 아주 섬세 능력 하나 누군가 생각 잘못 된 것 임 이해 다는 틀린 믿음 능력 쪽 능력 확인 과정 에서 잃 기 전 까지 진가 를 인정받 지 못하 인지 능력 중 하나 인 자제력 우리 삶 에서 핵심 적 역할 수행 게 된다 물론 자기 가축화 과정 시작 될 때 부터 극도 자제력 지녔 던 것 우리 종 뿐 과정 겪 으며 감정 반응 더욱 억제 함 으로써 신중 게 판단 고 행동 우리 능력 한층 더 강화 된 것 쪽 친화력 상승 자기 가축화 징후 를 촉발 한다는 사실 알 았 그렇 다면 핵심 발달 발달 속도 나 시기 따라 완전히 다른 몸체 유형 만들 어 지 기 도 고 사회 적 행동 도 영향 미친다고 한다 발달 기간 연장 여부 따라 협력 적 행동 강화 될 도 다고 보 고 이런 발달 패턴 사람 뿐 만 아니 라 보노보 침팬지 동물 에서 도 나타났 다는 연구 결과 를 내놓 았 사람 동물 차이 사회 적 문제 를 해결 느냐 없 느냐 여부 인 것 다시 말 해서 우리 종 일어난 친화력 선택 다른 동물 다른 것 우리 종이 보노보 처럼 전반 적 인 포용력 만 강화 된 게 아니 라는 점 우리 종 집단 구성원 정의 를 확장 시킨다 쪽 우리 모르 사람 둘러싸여 살아가 지만 그 그냥 참 고 견뎌 주 정도 아니 라 적극 적 으로 서로 를 돕 는다 쪽 점 동물 다른 점 친화력 우리 종 성공 으로 이끌 었 다는 생각 새롭 지 않 하나 종 으로서 우리 더 똑똑 해졌 다는 생각 도 마찬가지 우리 발견 것 두 생각 사이 놓여 사회 적 관용 높 아 지 면서 인지 능력 특히 의사소통 협력 관련 기능 변화 일어났 다는 점 쪽 타자 친절 우리 종 특성 보노보 와 일치 지만 사람 경우 친절 함 특정 타인 만 해당 된다 우리 집단 정체 성 토대 로 타인 판단 한다 자신 속한 집단 향한 사랑 정체 성 다른 타인 대해서 두려움 공격 성 높이 방향 으로 작동 기 도 한다 쪽 점 간과 해서 안 된다 인간 연민 공감 능력 이러 본성 함께 예측 고 개발 해야 지만 사회 적 으로 야기 된 문제 사회 적 해법 필요 다는 사실 또한 기억 해야 겠 가장 바람직 도시 모습 다양 국가 와 민족 인종 성 정체 성 섞인 활기 넘치 공동체 를 이루 공간 다양 성 사람 간 교류 를 활성 화 시키 며 혁신 경제 적 성장 이끌 고 사회 관용 강화 시킬 것 쪽 도시 서로 다른 배경 다양 관점 경험 지닌 삶 자유 롭 게 섞여 생각 교환 공간 되 어야 한다 우리 큰 규모 집단 안 에서 협력 며 살아갈 때 가장 창조 적 고 생산 적 인 종이 쪽 서식지 바뀌 어도 우리 본성 변하 지 않 것 서로 다양 성 인정 고 그 안 에서 최선 관용 베풀 면서 건강 사회 를 만들 어 나가 야 것 오랜 연구 와 분석 관찰 끝 세상 나온 를 읽 독자 마음 마음 모여 지구 를 함께 나눠 쓰 고 인간 동물 더 큰 사랑 공감 나눌 기 를 바란다는 작가 소망 꼭 이루 어 졌으면 좋 겠 또한 어떠 순간 도 다정 함 승리 전략 되 세상 되 었 으면 좋 겠 다는 바람 가져본다 책 마지막 페이지 를 덮 독자 조금 더 다정 고 따뜻 사람 되 고 싶 어 질 것 그것 희망 라고 부르 고 싶',
#  '불현듯 나 이제 정말 부르주아 구나 라는 생각 너무 늦 었 다는 생각 어 아찔 나중 첫 발령 기다리 며 여름 보내 면서 모든 것 설명 해야 만 한다는 생각 찾아왔 아버지 와 그 인생 대해 그리고 사춘기 시절 그 와 나 사이 찾아온 거리 대해 말 고 쓰 고 싶 었 계층 간 거리 나 이름 없 특별 거리 대해 마치 이별 사랑 처럼 아니 에르노 남자 자리 아니 에르노 책 남자 자리 년 노벨 문학상 수상 작가 인 아니 에르노 책 남자 자리 를 읽 었 습니다 조은미 나 천천히 쓰 고 사실 선택 집합 에서 인생 잘 나타내 실타래 를 밝혀내 기 위해 애쓰 면서 조금 씩 아버지 만 특별 모습 잃 어 듯 기분 글 초안 온통 자리 를 차지 고 생각 혼자 뛰어다닌다 반대 로 기억 장면 슬며시 미끄러져 들어오 게 두 면 아버지 모습 그대로 보인다 아니 에르노 남자 자리 시 중산 층 어울리 기 시작 면서 사람 내게 내 취향 재즈 아니 면 클래식 타 티 아니 면 르네 클레르 를 물 었 때 그것 만 으로 도 내 다른 세계 로 건너왔 음 깨닫 게 됐 아니 에르노 남자 자리 나 아버지 남자 자리 를 읽 고 나 니 아버지 대해 자주 생각 게 됩니다 조은미 아니 에르노 아버지 삶 대해서 쓴 책 인 를 읽 었 습니다 책 그리 두껍 지 않 고 문장 도 담백 고 수수 기 금세 읽 습니다 저 달 사이 두 번 읽 어 보 았 어요 금세 읽 다고 말씀 드렸 지만 어쩐지 천천히 읽 게 되 고 읽 다가 자꾸 멈추 게 되 책 입니다 아버지 돌아가 시 고 나 서 그 삶 기록 기 위해 아니 에르노 책 씁니다 글�
#  '교보문고 교보 손 글씨 김혜남 서체 를 공개 고 무료 로 배포 한다고 일 밝혔 서체 작년 제회 교보 손 글씨 대회 에서 일반 부문 으뜸상 수상 김혜남 씨 손 글씨 수상 당시 세 였 던 김혜남 씨 역대 최고령 수상자 로 화제 된 바 서체 제작 윤디 자 인 그룹 맡 았 글자 흐름 꺾임 에서 손 글씨 만 특징 적 인 측면 살리 면서 가독성 판독 성 높였 가로 와 세로획 간 굵기 차이 작 고 전체 적 인 글씨 형태 세로 로 길 고 얇 펜글씨 스타일 로 서정 적 인 글 본문 용 적합 교보 손 글씨 김혜남 서체 교보 손 글씨 대회 상작 으로 만들 어 진 번 째 폰트 지난 상작 포함 해 교보문고 홈페이지 공식 인 스타 그램 채널 통해 무료 다운로드 가능 또한 인쇄물 웹 모바일 광고 물 영상 자료 다양 영역 에서 자유 롭 게 사용 교보문고 오 일 까지 공식 인 스타 그램 채널 팔 로 우하 고 관련 게시 글 공유 면 추첨 통해 사은품 증정 한다 올해 월일 제회 교보 손 글씨 대회 로 시작 으로 손 글씨 문화 확산 캠페인 시행 예정',
#  '서울 뉴시스 신재우 예 스 창립 주년 맞 아 새로운 브랜드 아이덴티티 를 공개 일 예 스 새로운 와 함께 사람 다양 문화 콘텐츠 를 통해 삶 영감 동기 를 선사 한다 를 새로운 브랜드 비전 으로 채택 다고 밝혔 신규 예 스 상징 인 스마일 파란색 계승 예 스 브랜드 고유 유산 인 스마일 눈 내재 읽 고 보 경험 통해 삶 동기 를 부여 문화 콘텐츠 플랫 폼 상징 한다 필기체 지적 면서 도 경쾌 무드 형태 유연 사고 와 유쾌 성격 지닌 예 스 페르소나 를 표현 고자 다고 설명 한편 예 스 년 국내 최초 인터넷 서점 으로 시작 해 년 간 인터넷 서점 분야 위 를 유지 고 도서 로 시작 해 전자책 공연 음반 연재 문화 콘텐츠 전반 으로 사업 영역 확장 고',
#  '서울 뉴시스 강진아 문화 체육관 광부 중앙 부처 지방 자치 단체 공공 기관 산재 여개 국민 생활 지원 정책 권 책 담 았 지난달 일 발간 국민 든든 게 희망 사다리 국민 생활 밀접 정부 지원 제도 최신 정보 를 수록 생애 주기 별 아동 청년 중 장년 어르신 분야 별 복지 일자리 문화 건강 안전 로 나누 어 지원 대상 지원 내용 신청 방법 문 처 단계 필수 정보 만 뽑 아 구성 지난 년 부터 발행 했으며 올해 기존 희망 사다리 이름 희망 사다리 로 바꿨 통합 공공 임대 주택 뉴 홈 주거 지원 정책 냉난 방비 지원 정보 를 담 에너지 복지 취약 계층 위한 정부 직접 일자리 현 정부 주요 게 추진 약자 복지 정책 빠짐없이 담겼 또 년 신규 지원 제도 신청 해야 받 숨 지원금 찾 기 를 위한 일자리 자산 형성 주거 지원 사회 복지 제도 이야기 예술 인 이야기 할머니 도 실 었 어르신 지원 편의 경우 글씨 를 키워 어르신 쉽 게 정보 를 찾 도록 책자 지자체 민원실 이나 전국 도서관 보건소 우체국 은행 다중 이용 기관 비치 한다 인터넷 모바일 로 볼 전자책 정책 주간지 공감 누리집 이나 교보문고 예스 주요 인터넷 서점 에서 무료 로 내려 받',
#  '스마일 모양 로고 로 친숙 던 예 스 창립 주년 맞 아 새로운 브랜드 아이덴티티 를 일 공개 주년 계기 로 문화 콘텐츠 플랫 폼 기업 으로 도약 의미 변화 대한민국 최초 인터넷 서점 으로 시작 예 스 창립 주년 맞 아 사람 다양 문화 콘텐츠 를 통해 삶 영감 동기 를 선사 한다는 브랜드 비전 함께 새로운 얼굴 선보이 게 됐 예스 신규 기존 핵심 상징 인 스마일 블 루 컬러 를 계승 면서 도 라이프 모티 베 이터 라는 새로운 비전 의지 를 담 았 브랜드 고유 유산 인 스마일 눈 내재 읽 고 보 경험 통해 삶 동기 를 부여 문화 콘텐츠 플랫 폼 으로서 예스 를 상징 한다 또한 필기체 지적 면서 도 경쾌 무드 형태 유연 사고 와 유쾌 성격 지닌 예 스 페르소나 를 표현 고자 예스 관계자 고객 만족 우선 가치 로 여겨온 예 스 창립 주년 맞 아 새로운 시대 맞 의지 와 비전 담 를 게 되 었 다며 이번 공개 를 시작 으로 고유 가치 를 계승 면서 도 새로운 모습 선보이 려는 예 스 두 번 째 시작 많 관심 부탁 드린다 라고 말',
#  '디지털 데일리 이나연 난 놈 만 패 한국 코미디 영화 역사 획 그 었 다고 회자 되 주유소 습격사건 에서 배우 유오 성 이런 명대사 를 날린다 자칭 매일 뛰 남자 이하 매 뛰 남 원윤식 네이버 대외 커뮤니케이션 전무 달리기 에서 놈 바로 문지방 라고 강조 한다 일단 문밖 으로 나서 기 만 면 달리 기 반 이상 성공 다는 의미 원윤식 전무 여년 전 심근 경색 으로 쓰러진 이후 건강 위해 뛰 기 시작 년 전 부터 본격 적 인 울트라 러너 마라 토너 보다 더 장거리 를 뛰 러너 삶 살 고 매일 평균 킬로미터 를 달리 것 일상 에서 빼놓 없 루틴 으로 자리 잡 았 다는 그 지난해 월 부터 네이버 블로그 매일 뛴 기록 그날 감상 적 었 그렇게 차곡차곡 쌓인 기록 지난 월 끔찍 해서 오늘 도 달립니다 라는 권 책 으로 탄생 원 전무 를 매일 달리 게 힘 무엇 일까 최근 서울 마포구 카페 에서 원 전무 를 만났 달리 기 도 튼 그 도 운동 화 끈 고쳐 매 고 밖 으로 나가 기 까지 하루하루 자신 갈등 라고 말 한다 안전 이불 속 주 안정 감 깨 건 생각 보다 큰 의지 필요 해서 그런데 도 원 전무 잠 줄이 면서 까지 뛰 건 달리 지 않 일상 더 힘들 어 지 느낌 몇 번 이나 경험 기 직업 특성 상 사람 만나 게 주 업무 보 니 스스로 집중 달리기 매력 느꼈 다는 것 원 전무 설명 사내 와 동네 러닝 동호회 에서 활동 면서 도 혼자 만 달리기 를 즐기 것 도 그래서 그 달리 기 명상 동질 성 즉 내면 으로 향하 구실 제공 한다는 이야기 
명히 나타난다 목공 일 손가락 두 개 잘린 인선 고통 그토록 큰데 겪 었 고통 얼마 만큼 컸 을지 를 한강 미루 어 짐작 려 한다 그 고통 총탄 뚫리 고 몽둥이 얻어맞 고 칼 베여 죽 사람 넘어와 살아남 인선 어머니 와 그녀 견딘 세월 인선 오늘 이르 기 까지 진득 게 붙 어 한강 인선 입 빌려서 말 한다 인간 인간 어떤 일 저지른다 해도 더 이상 놀라 지 않 것 같 상태 로 스스로 변형 되 것 느꼈 다고 말 심장 깊 곳 에서 무엇 인가 이미 떨어져 나갔으며 움푹 파인 그 자리 를 적시 고 나온 피 더 이상 붉 지 도 힘차 게 뿜 어 지 지 도 않 으며 너덜너덜 절단면 에서 오직 단념 만 멈춰 줄 통증 깜박이 그게 엄마 다녀온 곳 란 걸 나 알 았 다고 말 다가서 면 다가설수록 다가서 내면 파괴 비극 그 비극 에서 살아남 뒤쫓 아 파괴 해 왔 다는 걸 몸소 비극 추적 해 온 한강 증언 고 것 그러므로 사건 년 간 학살 에서 끝나 지 않 는다 반세기 동안 그 폭력 성 그치 지 않 고 지속 돼온 것 한강 소설 에서 내보이 려 것 도 바로 그것 작가 소설 폭력 대한 것 도 학살 대한 것 도 증오 대한 것 도 아니 라고 말 한다 한강 소설 사랑 대한 것 라고 이야기 한다 사랑 무엇 일까 나 보다 도 다른 누구 를 먼저 생각 것 그리하여 기꺼이 나 를 내던지 것 군경 총탄 앞 몸 던져 아이 를 막아선 어머니 처럼 저 보다 도 다른 무엇 위하 것 인선 위해 경 폭풍우 를 뚫 고 제주 깊 마을 로 향했 단 번 본 작 생명 위하 여 경 치 앞 보이 지 않 추운 산길 더듬 어 나아갔 얼핏 번 지나친 게 전부 인 인선 어머니 와 단 번 만난 적 없 제주 숨진 영혼 위해서 경 나무 를 깎 고 그것 세우 고 어쩌면 이제껏 쓰인 적 없 글 까지 써내려갈 것 한강 매 순간 고통 마주 며 를 완성 것 처럼 말 나 인선 작업 경하 변화 와 한강 소설 이끈 것 모두 사랑 었 다고 믿 는다 한강 소설 사랑 대한 것 라고 말 었 던 것 도 바로 라고 나 그렇게 믿 는다 김성호 서 평가 얼룩소 도 함께 실립니다 김성호 독서 만세 를 검색 면 더 많 글 만날 습니다',
#  '서울 뉴시스 신재우 소설가 홍 년 만 신작 씨름 왕 문학 사상 펴냈 이번 책 지난해 문예지 통해 연재 던 편의 단편 모은 연작 소설 집 씨름 왕 었 던 아버지 시한부 선고 와 죽음 이른 파경 맞 결혼 생활 주인공 지현 겪 이야기 를 중심 으로 단편 이어진다 소설 속 에서 인생 씨름 비유 된다 씨름 처럼 희비 뒤엉켜 엎치락뒤치락 고 승리 를 거머쥐 기 위해 상대 를 단단히 휘어잡 아야 것 마치 굴곡진 인생 같 그러 순간 속 에서 소설 우리 씨름 경기 에서 처럼 승부수 를 던져야 순간 언제 인지 를 생각 게 한다 문학 동네 소설 상 제회 상작 미터 없 어 문학 동네 출간 됐 소설가 양지 예 지난 년 신춘문예 를 통해 적록 색맹 가진 학생 선생 이야기 를 담담 게 그린 단편 소설 나 로 등단 이번 첫 장편 소설 통해서 년 전 미얀마 에서 측량 천재 라고 불리 여성 행방불명 사건 에서 출발 한다 왜 완벽 측정 믿 지 않 으세요 그런 건 없 으니까요 시간 흐르 면 자도 변하 고 수준 원점 도 달라지 고 기껏 잰 산 높이 도 변하 잖아요 완벽 측정 라는 것 만큼 공허 개념 또 을까요 본문 쪽 중 이야기 실종 배후 를 파헤치 한편 측정 그 자체 대해 질문 한다 불 확실 세계 속 에서 확정 없 대상 측정 없 고 측정 없 대상 정의 없 다는 깨달음 속 획정 것 너머 세계 를 보여준다',
#  '카카오톡 에서 모르 사람 단체 채팅 방 초대 려고 경우 거절 일 카카오 업데이트 를 통해 카카오톡 이용자 편의 성 계정 보안 강화 여러 기능 추가 다고 밝혔 이번 업데이트 로 그룹 채팅 방 참여 설정 기능 정식 추가 됐 카카오톡 친구 목록 없 사람 그룹 채팅 방 초대 려고 경우 이용자 수락 여부 를 묻 기능 이전 친구 목록 없 사람 도 이용자 의사 와 상관없이 그룹 채팅 방 초대 었 강제 로 초대 기능 악용 해 그룹 채팅 방 나가 도 끝없이 이용자 를 초대 카톡 감옥 카톡 지옥 라는 신종 괴롭힘 생기 기 도 카카오 업데이트 를 통해 그간 원 지 않 그룹 채팅 방 초대 로 스트레스 받 이용자 불편 해소 것 으로 기대 다만 카카오톡 친구 그룹 채팅 방 초대 경우 도 수락 여부 를 묻 기능 도입 할지 아직 계획 고 지 않 것 으로 전해졌 이번 업데이트 로 카카오톡 계정 보안 도 강화 됐 이용자 카카오톡 계정 실제 사용 중 인 전화 번호 맞 게 연동 돼 는지 확인 안내 메시지 설정 탭 주기 적 으로 노출 된다 현재 사용 중 인 번호 아니 라면 안 내창 통해 쉽 게 전화 번호 를 변경 카카오톡 지갑 서비스 홈 화면 도 개편 됐 기존 서비스 디지털 카드 와 전자 증명서 신원 증명 위한 항목 중심 었 개편 통해 금융 자산 도 포함 실제 지갑 같 기능 게 된 것 밖 도 그간 맥북 외 다른 에서 모두 지원 중 었 던 채팅 방 대화 내용 캡처 기능 맥북 도 도입 됐 캡처 옵션 인 프로필 배경 가리 기 추후 반영 될 예정 카카오톡 출시 전 기능 미리 사용 해 볼 실험실 도 개편 됐 이용자 카카오톡 실험실 이용 기 를 통해 사용 해 보 고 싶 기능 번 모두 활성 화 거나 필요 기능 만 활성 화 해 사용 해 볼 카카오 카카오톡 이용자 편의 성 향상 위한 다양 방안 고민 고 더 발전 된 서비스 를 선보이 기 위해 노력 고 다며 앞 으로 도 이용자 니즈 를 만족 시키 고 서비스 안정 성 편의 성 향상 기 위한 업데이트 를 지속 선보여 사람 사람 사이 커뮤니케이션 더 가깝 고 안 전하 게 것 라고 전했',
#  '쏘 시스템 이번 플랫 폼 공급 통해 국내 식음 기업 디지털 트랜스 포메이션 지원 더욱 가속 화 겠 다는 의도 삼성 웰 스토리 코로나 팬더 믹 이후 원재료 가격 폭 급변 가격 변동 성 대응 기 위해 중앙 조리 시설 에서 반 조리 된 제품 각 사내 식당 공급 계획 를 위해서 제품 개발 프로세스 를 관리 고 조직 간 협업 신속 의사 결정 지원 시스템 필요 성 느껴 쏘 시스템 식음료 연구 개발 프로세스 특화 된 식품 전문 솔루션 선택 삼성 웰 스토리 이번 구축 통해 제품 개발 프로세스 를 지원 협업 플랫 폼 확보 게 되 었 또한 다양 프로젝트 를 쏘 시스템 기반 플랫 폼 내 에서 유기 적 으로 관리 함 으로써 식음 업계 트렌드 를 빠르 게 선도 예정 삼성 웰 스토리 관계자 쏘 시스템 솔루션 업계 에서 이미 검증 된 솔루션 으로 상품 개발 도 최적 화 된 환경 제공 것 으로 기대 된다 며 를 통해 식 재료 와 레시피 정보 를 데이터 기반 으로 관리 함 으로써 고객 더욱 믿 고 선택 먹거리 를 제공 계획 라고 언급 삼손 카우 쏘 시스템 아시아 태평양 지역 수석 부사장 쏘 시스템 글로벌 식품 기업 디지털 트랜스 포메이션 경험 바탕 으로 국내 에서 도 식음료 업계 와 기업 특화 된 솔루션 구축 며 식음료 시장 에서 괄목 만 성과 를 거두 고 다며 이번 삼성 웰 스토리 솔루션 구축 역시 그 일환 중 하나 로 앞 으로 도 식음 기업 디지털 트랜스 포메이션 적극 지원 계획 라고 밝혔 디지털 데일리 이상일 쏘 시스템 글로벌 식음 서비스 기업 삼성 웰 스토리 제품 수명 주기 관리 프로그램 인 솔루션 구축 프로젝트 쏘 시스템 익스 피리 언스 플랫 폼 공급 한다고 일 밝혔',
#  '애플 버넷 엑스 와 진행 억 만 달러 약 천억 원 규모 소송 항소심 에서 승리 최근 더 레지스터 외신 따르 면 미국 연방 순회 항소 법원 버넷 엑스 제기 억 만 달러 규모 소송 기각 한다고 판결 이번 판결 쟁점 인 버넷 엑스 특허 개 무효 라는 미국 특허 상표 청 결정 반영 것 라고 법원 밝혔 이번 소송 버넷 엑스 년 애플 페이스타임 온디 멘 드 기능 추가 과정 에서 보안 네트워크 와 통신 링크 관한 특허 를 위반 다고 지적 면서 법 적 공방 시작 됐 같 해 진행 된 첫 소송 에서 애플 패소 미국 텍사스 동부 지역 법원 배심 원단 애플 버넷 엑스 특허 권 침해 다면서 억만 달러 를 지불 라고 평결 판사 역시 배심원 평결 그대로 인정 애플 측 판결 불복 며 항소 나섰 약 년 간 이어진 소송 중 미국 특허청 년 월 이전 출간 된 간행물 에서 특허 기술 관련 내용 확인 다며 소송 엮인 특허 종 무효화 버넷 엑스 특허 무효 로 자연 스럽 게 애플 특허 침해 소송 에서 벗어나 며 억만 달러 를 지불 책임 도 사라졌 버넷 엑스 켄달 라센 최고 경영자 우리 이번 판결 실망 고 동일 특허 대한 과거 판결 비추 어 연방 순회 법원 결정 동의 지 않 는다며 잠재 적 으로 재 심리 또는 인증서 검토 를 모색 것 포함 여 사용 가능 모든 옵션 고려 고 다고 성명서 를 통해 밝혔',
#  '티맥스 소프트 실적 표 사진 티맥스 소프트 사진 티맥스 소프트 티맥스 소프트 대표 이형배 지난해 매출액 천억 원 영업 이익 억 원 기록 다고 일 밝혔 연결 기준 당기 순이익 억 원 티맥스 소프트 전 세계 경제 침체 속 에서 도 지난해 매출 영업 이익 당기 순이익 각각 전년 대비 약 증가 며 사상 최대 실적 거뒀 다는 입장 회사 작년 부터 사업 별 로 독립 조직 체제 를 운영 사업부제 를 실시 바 사업부제 기업 책임 투명 경영 내걸 고 의사 결정 효율 성 비즈니스 경쟁력 높이 기 위해 만든 정책 티맥스 측 이러 효과 로 각 사업 부문 에서 디지털 환경 변화 맞춰 제품 고도 화 고 풍부 사업 수행 경험 차별 화 된 서비스 를 앞세워 고른 성과 를 냈 다는 입장 오픈 소스 중심 통합 미들웨어 플랫 폼 하이퍼 프레임 통해 참여 년 제차 범 정부 정보 자원 통합 구축 사업 국내 지방 은행 시스템 경쟁력 강화 사업 대표 적 예 티맥스 소프트 올해 하이퍼 프레임 슈퍼 프레임 필두 로 국내 클라우드 사업 더 확장 방침 올해 초 출범 를 통해 글로벌 비즈니스 도 강화 계획 특히 글로벌 컨설팅 기업 파트너십 적극 활용 해 고객 비즈니스 목적 부합 메인프레임 현대 화 와 클라우드 통합 서비스 를 제공 예정 이형배 티맥스 소프트 대표 올해 도 탄탄 실적 다질 도록 클라우드 제품 더욱 고도 화 고 서비스 형 소프트웨어 비즈니스 모델 적용 해 서버 기반 미들웨어 확장 신 성장 동력 확보 것 다며 중 장기 적 성장 도모에 적극 주력 겠 다고 전했',
#  '알트만 지난 일 현지 시간 자신 트위터 오 월 오픈 이용자 나 개발자 전반 관심 사람 만나 오픈 투어 시작 한다며 정책 입안자 대화 기 를 바란다고 밝혔 오픈 이번 투어 를 통해 오픈 사용 자 개발 자 전 세계 인공 지능 관심 모든 사람 연결 것 목표 로 한다는 설명 현재 알트만 트위터 를 통해 소식 공유 고 사람 투어 초대 해 대한 피드백 기능 요청 기타 생각 공유 도록 고 알트만 방문 도시 서울 비롯 해 토론토 워싱턴 리우데자네이루 라고스 마드리드 브뤼셀 뮌헨 런던 파리 텔아비브 두바이 뉴델리 싱가포르 자카르타 도쿄 총 곳 디지털 데일리 이상일 챗 를 개발 미국 오픈 샘 알트만 최고 경영자 한국 온다',
#  '웹 케 시 그룹 이번 공채 를 통해 개발 디자인 상품 사업 영업 행정 다양 직무 인재 를 모집 한다 입사 지원 월 일 까지 사람 인 웹 케 시 채용 공고 를 통해 가능 며 서류 전형 이후 면접 전형 거쳐 선발 한다 최종 합격자 개월 간 인턴 근무 후 평가 를 통해 정규직 으로 채용 되 며 직무 따라 웹 케시 쿠 콘 비즈 플레이 비플 페이 웹 케시 글로벌 로 소속 결정 된다 웹 케 시 그룹 인턴 정규직 전환율 이상 며 정규직 신입 연봉 만 원 선 웹 케 시 그룹 코스닥 상장 사 인 웹 케시와 쿠 콘 비롯 해 비즈 플레이 비플 페이 그룹 사 를 두 고 으며 자금 관리 솔루션 부터 비즈니스 데이터 디지털 경비 지출 관리 플랫 폼 비플 제 로페이 앱 전문 화 된 사업 분야 를 영위 전문 기업 웹 케 시 그룹 임직원 경쟁력 향상 휴식 위해 최고 복지 제도 를 제공 한다 카페 헬스 장 릴렉스 룸 사내 복지 시설 운영 임직원 전용 휴양 시설 운영 주택 자금 자녀 학자금 지원 경조사 지원 안식 휴가 지원 선택 적 복지 제도 운영 탄력 근무 제 시간 선택 제 근무 시행 중 디지털 데일리 이상일 웹 케 시 그룹 회장 석창 규 년 상반기 신입 사원 공개 채용 진행 한다고 밝혔',
#  '디지털 데일리 이종현 작년 클라우드 업계 에서 기념비 적 인 해 라고 만 합니다 주요 클라우드 서비스 기업 인 와 클라우드 사업 부문 독립 법인 으로 분할 기 인데요 기업 독립 으로 보다 상세 시장 파악 가능 해 졌 습니다 클라우드 시장 선명 해진 상황 입니다 대다수 기업 년 사업 실적 담 감사 보고서 나 사업 보고서 제출 마무리 습니다 국내 주요 실적 도 금융 감독원 전자 공시 시스템 에서 확인 일부 기업 경우 모회사 보고서 를 통해서 또 일부 기업 독립 된 법인 으로서 보고서 를 제출 습니다 가장 눈길 끄 것 네이버 클라우드 입니다 네이버 클라우드 년 매출액 조억 원 당기 순 손익 억 원 기록 습니다 국내 중 매출 조원 넘 것 네이버 클라우드 최초 입니다 전년 대비 매출액 당기 순 손익 증가 는데요 당기 순 손익 도 크 게 늘 었 본격 적 인 수익 화 성공 첫해 입니다 네이버 클라우드 올해 사업 실적 더 확대 될 전망 입니다 네이버 클 로바 웨일 파파 고 자사 엔터 프라이즈 대상 기술 부문 네이버 클라우드 로 집중 시켰 습니다 네이버 기업 대상 정보 기술 사업 데 모은 만큼 시너지 생길 것 으로 기대 됩니다 네이버 이어 두 번 째 로 높 매출액 기록 것 클라우드 입니다 클라우드 매출액 억 원 당기 순 손익 억 원 기록 습니다 년 월 설립 된 만큼 사업 보고서 전년 도 실적 공개 되 지 않 았 는데요 다만 클라우드 분기 매출 기에 온전 연 매출 로 보 기 어렵 습니다 사업 보고서 에서 클라우드 매출 년 분기 억 원 분기 억 원 분기 억 원 으로 기재 습니다는 최근 힘든 시기 를 보내 고 습니다 차기 대표 후보 줄 사퇴 로 전례 없 경영 공백 맞이 탓 입니다 를 통신 기업 아닌 디지털 플랫 폼 기업 이하 디지 코 으로 거듭나 도록 것 구현모 전 대표 주요 업적 으로 꼽 힙 니다 디 지코 전략 에서 수혜 를 누린 것 클라우드 입니다 전폭 적 으로 지원 던 그룹 사 수장 공백 클라우드 위기 로 작용 습니다 클라우드 와 마찬가지 로 작년 월 출범 클라우드 도 단독 법인 으로 처음 감사 보고서 를 냈 습니다 년 매출액 억 원 당기 순손 실익 억 원 으로 적자 를 기록 는데요 클라우드 와 마찬가지 로 분기 매출 합인 만큼 올해 실적 규모 를 더 키울 것 으로 보입니다 그동안 더 해 협업 도구 나 해외 클라우드 관리 서비스 기업 계열사 실적 기술 매출 로 집계 해 발표 독립 법인 되 면서 구체 적 인 실적 공시 게 됐 습니다 그런 클라우드 올해 목표 로 제시 것 순익 분기점 달성 인데요 그간 매출 성장 만 집중 다면 올해 부터 본격 적 으로 수익 화 나서 겠 다는 전략 인데 광주 인공지능 데이터 센터 중심 으로 각지 건립 중 인 데이터 센터 제 역할 느냐 주목 만 요소 입니다 카카오 엔터 프라이즈 국내 중 가장 가파르 게 매출 키운 기업 입니다 년 매출액 억 원 전년 대비 나 성장 습니다 그러나 늘어난 매출 만큼 이나 당기 순손실 도 커졌 는데요 카카오 엔터 프라이즈 당기 순손실 년 억 원 에서 년 억 원 으로 증가 습니다 카카오 엔터 프라이즈 주요 중 가장 많 인력 운용 고 기업 입니다 기업 감사 보고서 따르 면 년 월 기준 명 근무 고 습니다 년 기준 네이버 클라우드 여명 보다 많 경쟁 기업 대비 이익 확대 절실 합니다 대외 환경 국내 썩 우호 적 지 않 습니다 연초 클라우드 보안 인증 개편 됨 따라 해외 공공 클라우드 시장 진입 가능 성 커졌 습니다 거기 정부 기조 도 클라우드 산업 인프라 에서 소프트웨어 로 옮겨 중 입니다 국내 로서 궁지 몰린 상황 인데요 다만 챗 봇 챗 불러온 인기 기회 로 작용 다는 목소리 나옵니다 경기 침체 예상 되 면서 긴축 나섰 던 기업 활용 위해 지갑 여 모양새 입니다 특성 상 클라우드 기반 인프라 를 이용 밖에 없 습니다 마침 국내 와 같 신 기술 집중 해 온 만큼 적 지 않 기회 생길 것 으로 전망 됩니다 기반 차세대 보안 비서 시큐리티 코 파일럿 공개 자사 사이버 위협 인텔리 전 스 와 전문 지식 결합 시킨 서비스 로 업계 최초 생성 보안 서비스 시큐리티 코 파일럿 방어 자 보안 환경 상황 파악 고 기존 인텔 리전 스 를 학습 거나 위협 활동 상관 관계 를 이해 보다 많 정보 기반 효율 적 인 의사 결정 내리 데 활용 되 도록 설계 됐 명령어 프롬프트 답변 것 기존 챗 와 유사 하나 특화 된 만큼 더 높 정확도 를 보일 전망 다가 국내 스타트업 대상 으로 지원 프로그램 육성 전략 소개 스타트업 위크 개최 스타트업 위한 비즈니스 핵 시 트렌드 지원 고 활동 전반 공유 됐 다는 행사 를 통해 스타트업 프로그램 통해 한국 만여 개 달하 스타트업 대한 혁신 지원 고 다고 강조 와 함께 서비스 형 소프트웨어 스타트업 육성 위한 프로그램 진행 계획 도 공유 이기혁 코리아 스타트업 에코 시스템 총괄 월 부터 엑 셀러 레이터 프로그램 통해 스톤 벤처 스 벤처 스 물론 실리콘 밸 리 직접 참여 해 주간 멘토링 통해 글로벌 진출 기회 를 주려 한다고 말 한글 컴퓨터 이하 한컴 교육 공공 시장 공급 자사 한컴 오피스 네이버 클라우드 하이퍼 스케일 초 거대 하이퍼 클 로 바를 적용 기 위한 전략 적 파트너 십 체결 이번 파트너십 따라 오 월 공개 예정 인 하이퍼 클로 바 한컴 오피스 적용 돼 선보여 진다 하이퍼 클로 바 학습 데이터 중 한국어 비중 이상 인 것 특징 영어 특화 돼 오픈 챗 비해 한국 사회 법 제도 문화 적 맥락 대한 이해도 높 것 으로 기대 된다 양사 협의 체 를 구성 해 맞춤 형 기능 공동 개발 사업 화 를 공동 진행 예정 시 코프 와 함께 브로드밴드 인프라 자동화 솔루션 구축 테라 폼 볼트 패커 노 마드 시 코프 솔루션 전반 통해 높 가시성 자동 화 된 인프라 관리 보안 강 화 라는 목표 를 달성 다는 설명 브로드밴드 이번 인프라 자동화 솔루션 구축 전 각 개발자 지라 를 통해 본인 개발 환경 필요 인프라 를 요청 고 이후 운영 자 요청 된 리소스 를 프로비저닝 하고 엑셀 에서 리소스 를 수동 으로 업데이트 방식 으로 업무 를 수행 를 셀프 서비스 포털 에서 개발자 리소스 를 선택 고 관리자 를 승인 면 리소스 자동 으로 프로비저닝 도록 개선 프라이빗 클라우드 를 위한 사업 전개 중 인 오케 스트로 년 상반기 억 원 규모 시리즈 투자 유치 를 추진 한다 오케 스트로 창업 년차 인 작년 인 베스트 먼 트 로부터 억 원 시리즈 투자 를 유치 바 오케 스트로 멀티 하이브리드 클라우드 를 위한 클라우드 관리 플랫 폼 오 케 스트로 를 중심 으로 클라우드 관련 솔루션 제공 기업 오케 스트로 자사 대 규모 클라우드 환경 통합 관리 으며 국가 정보 자원 관리원 국방 통합 데이터 센터 도입 돼 사용 중 라고 강조 클라우드 베스 핀 글로벌 아이덴티티 액세스 관리 솔루션 기업 옥 타 제품 판매 영역 미국 중동 북아프리카 동남아시아 일본 글로벌 개국 으로 확대 한다고 밝혔 옥 타 분야 리더 기업 그 무엇 도 믿 지 말 라는 보안 방법 론 제로 트러스트 구현 위해 꼭 갖춰야 기술 로 손꼽히 고 베스 핀 글로벌 자사 해외 법인 중심 으로 옥 타 상품 판매 를 확대 고 를 계기 로 클라우드 보안 사업 도 한층 강화 겠 다는 포부',
#  '클라우드 독립 법인 출범 주년 맞이 지난해 성과 힘입 어 올해 인공지능 기술력 적극 활용 해 나갈 방침 다일 관련 업계 따르 면 클라우드 지난해 월 일 년 부터 제공 해 오 던 클라우드 서비스 를 더욱 전문 화 기 위해 클라우드 전문 서비스 기업 으로서 독립 법인 형태 로 출범 이후 년 간 공공 금융 정보 기술 게임 다양 영역 고객 사 를 확보 고 클라우드 지난해 공공 부문 클라우드 전환 사업 에서 수주 기관 기준 시장 점유 율 기록 며 선두 를 달성 또 신한 금융 투자 상상 인 저축 은행 멀티 클라우드 전략 기반 금융 권 고객 연이 어 확보 같 성과 를 바탕 으로 클라우드 중심 된 지난해 기술 부문 매출 전년 대비 증가 클라우드 생태 계 조성 도 서비스 중심 으로 주요 성과 를 달성 독립 법인 출범 이후 개인 사용 자 포함 서비스 이용 고객 출범 이전 대비 상승 년 간 클라우드 마켓 플레이스 신규 솔루션 여 개 입점 됐으며 자체 적 으로 개발 데이터 활용 쿠 버네 티스 머신 러닝 신규 서비스 형 소프트웨어 를 개 선보였 전체 파트너 사 여 개 로 독립 법인 출범 직후 와 비교 때 상승 지방 권역 사업 함께 고 지역 거점 파트너 여 개 로 이전 보다 배 증가 클라우드 지난 년 간 성과 를 발판 삼 아 미래 성장 박차 를 가할 계획 보유 기술력 서비스 형 인프라스트럭처 역량 융합 해 나갈 계획 또 개발 목적 고 성능 인프라 대한 준비 와 컨 택 센터 특화 상품 군 구성 해 나갈 계획 내부 쇄신 도 이어간 상품 별 유닛 조직 체계 를 도입 해 신속 사업 실행 위한 제반 준비 를
될 다는 점 도 지적 습니다 또 지난달 일 불거진 챗 결제 데이터 사용 자 대화 유출 문제 도 거론 습니다 보호 청 챗 위반 여부 를 조사 예정 인데요 국가 내 사업장 운영 기업 뿐 아니 라 전자 상거래 통해 해외 에서 주민 개인 정보 를 처리 기업 도 적용 됩니다 지난해 월 등장 챗 시장 나오 자 마자 세계 적 으로 큰 인기 를 끌 었 는데요 특히 월 사용 자 두 달 만 억 명 돌파 사용 자 억 명 세계 에서 가장 단시간 모은 서비스 로 기록 되 기 도 습니다 방대 데이터 를 수집 보 니 챗 정보 유출 민감 중국 러시아 같 나라 에서 사용 고 는데요 미국 에서 민간 기업 대학 일부 학교 도 챗 사용 금하 고 습니다 세계 적 투자 사 모건 미국 위 이동 통신 기업 버 라이 즌이 챗 사용 대표 기업 인데요 일본 에서 소프트 뱅크 직원 기업 기밀 챗 넣 지 말 라는 주의 를 주 기 도 습니다 우리 나라 에서 도 모 대기업 반도체 사업장 에서 챗 기업 정보 유출 사고 일어나 기 도 습니다 미국 기업 뿐 아니 라 대학 일부 공립 학교 에서 도 챗 사용 금했 는데요 우리 나라 대학 도 연세대 챗 대필 로 의심 되 과제 를 점 으로 처리 기 로 챗 쓴 건지 학생 쓴 건지 판별 기 위한 학교 고심 커지 고 습니다 미국 시각 지난달 일 와 디지털 정책 위한 센터 라는 긴 이름 가진 비 영리 단체 미국 연방 거래 위원회 민원 제기 해 지난달 출시 된 와 를 만든 오픈 회사 를 조사 라고 촉구 습니다는 공평 고 투명 며 설명 가능 해야 한다고 천명 조건 중 어느 하나 도 충족 지 못하 고 다는 겁니다 년 설립 된 우리나라 공정 거래 위원회 처럼 독과점 불공정 거래 를 규제 미국 대표 적 인 경제 규제 기관 입니다 미국 정부 공정 거래 기구 로 법무성 산하 독점 국 방 거래 위원회 로 이원화 해 운영 고 는데요 독점 국 민형사 사건 모두 를 민사사 건만 취급 것 다른 점 입니다 이번 청원 제기 워싱턴 사무실 습니다 보다 나 사회 를 위한 더 공평 고 더 공정 사회 를 만드 걸 기치 로 내걸 고 으며 설립자 겸 대표 마크 로텐버그 입니다 그 조지타운 법대 에서 프라이버시 법 가르치 고 으며 내 전문가 그룹 발간 정책 북 편집장 맡 고 습니다 하버드 칼리지 와 스탠포드 로스쿨 또 조지타운 대 에서 법학 석사 를 받 았 습니다 년 프라이버시 법 사회 라는 책 공동 저자 로 발간 고 유럽 의회 와 유럽 위원회 여러 기관 단체 정책 자문 고 와 법 관련 전문가 입니다 특히 년 와 민주주의 가치 라는 정책 실행 대한 책자 를 개 나라 에서 펴내 기 도 습니다 불 공평 고 기만 적 인 거래 행태 를 고 조사 명백 책임 다며 당연히 오픈 와 를 면밀히 조사 해야 한다며 를 압박 습니다 지난달 중순 출시 된 악성 코드 를 양산 거나 편향 된 데이터 학습 으로 고도 선전 악용 될 으며 또 채용 어 불 공평 젠더 인종 차별 초래 도 다고 우려 습니다 또 최근 결제 사고 에서 보 듯이 오픈 제품 인터페이스 차원 에서 심각 프라이버시 문제 를 안 고 다고 지적 습니다 특히 이후 상업 버전 출시 중단 물론 와 같 거대 경우 출시 전 를 평가 독립 기구 필요 다고 제안 습니다 이번 제소 조사 나설지 귀추 주목 되 는데요 최근 회의 에서 리나 칸 위원장 인공지능 주요 모델 특정 플랫폼 지배 되 지 않 도록 발전 과정 주목 고 다고 말 기 도 습니다 앞서 오픈 를 출시 면서 제품 데이터 를 어떻게 학습 는지 공개 지 않 아 논란 된 바 습니다 지난달 일 현지 시 각자 월스트리트 저널 따르 면 일련 테크 기업 경영자 와 학자 예컨대 일 론 머스크 테슬라 최고 경영자 와 딥 러닝 대부 요 슈와 벤 지오 캐나다 몬트리올 대 교수 거대 개발 최소 개월 정도 멈춰야 한다고 주장 습니다 대한 안전 표준 만들 고 야기 잠재 적 피해 를 막 때 까지 더 강력 고 새로운 생성 형 출현 막 아야 한다는 것 인데요 미국 비 영리 단체 인 미래 생명 연구소 지난 수요일 일 공개 거대 실험 중지하 자 제목 공개 서한 서명 습니다 서명자 여명 달하 는데요 서명자 중 머스크 와 벤 지오 교수 외 애플 공동 설립자 자 거물 스티브 위즈 니 악 세계 적 권위자 로 꼽히 스튜어트 러셀 버클리 캘리포니아 대 버클리 컴퓨터 과학 교수 이미지 생성 프로그램 개발 사 스테이빌 리티 에마드 모스 타 퀴 습니다는 공개서한 에서 모든 작업 자동 화 해야 냐면서 강력 시스템 그 효과 긍정 적 고 위험 관리 다는 확신 때 만 개발 해야 한다고 촉구 습니다 이어 서한 개발 사 더 강력 개발 일시 중지 한다는 사실 공개 적 으로 선언 해야 한다고 압박 면서 개발 중단 신속히 이뤄지지 않 는다면 정부 개입 해야 한다고 촉구 습니다 공개서한 모든 개발 중지 자고 지 않 았 습니다 앞 으로 나올 보다 더 막강 데이터 학습 훈련 개월 이나 그 이상 중지 자는 것 입니다 여기 다음 버전 인 도 들어가 는데요 오픈 아직 데이터 를 학습 지 않 고 다고 밝혔 습니다 챗 와 직접 경쟁 고 구글 도 비슷 제품 개발 중 인데요 이외 도 어도비 와 세일즈 포스 줌 같 전통 적 미국 기업 도 보다 고도 화 툴 선보였 는데요 특히 오픈 와 탄탄 협력 기반 으로 챗 가장 큰 수혜자 로 떠오른 마이크 로 소프트 사티야 나 델라 지난달 이제 레이스 시작 됐 우리 움직이 기 시작 고 더 빨리 움직일 것 다고 말 기 도 습니다 서명 동참 스태빌 리티 모스 타 퀴는 공개서한 공개 된 날 트위터 에서 서명 건 맞 지만 개월 간 개발 멈추 자는 건 동의 지 않 는다고 밝히 기 도 느 데요 가장 중요 당사자 인 와 구글 공개서한 아무런 코멘트 도 없 었 습니다 한편 서한 공개 오픈 를 비딱 시선 으로 보 고 머스크 외부 자문 위원 맡 고 뿐 아니 라 자금 도 후원 고 어 서한 내용 놓 고 의구심 받 기 도 는데요 실제 공개 서한 이름 올린 사람 중 일부 서명 가짜 였 다는 것 드러나 기 도 습니다 시진핑 중국 국가 주석 페이스 ...
#  '시 놀 로지 영상 보안 시스템 정보 유출 막 가이드라인 공개 사진 이미지 투데이 직책 별 영상 보안 시스템 접근 권한 설정 예 자료 시 놀 로 지 시 놀 로 지 일 최근 국내외 에서 발생 고 감시 카메라 영상 유출 예방 가이드라인 공개 셸리 추 시 놀 로지 세일즈 매니저 최근 발생 보안 영상 유출 사례 대부분 업데이트 없 시스템 방치 나 과다 권한 설정 원인 영상 감시 솔루션 도입 기업 시스템 보안 전송 보안 권한 보안 세 가지 측면 에서 점검 필요 다고 설명 카메라 와 영상 관리 시스템 운영 체제 와 펌웨어 새 기능 추가 으로 편의 성 향상 시키 정기 업데이트 뿐 만 아니 라 보 안 취약점 발견 시 신속 업데이트 보장 되 어야 한다 카메라 와 영상 관리 시스템 나 실시간 전송 보안 프로토콜 종단 간 암호 화 기술 적용 고 는지 도 확인 해야 한다 암호 화 되 지 않 상태 로 영상 전송 경우 관련 데이터 유출 될 가능 성 커진다 시스템 관리자 나 이용자 로그인 시 무 차별 대입 공격 막 다단계 인증 적용 업무 반드시 필요 최소한 권한 만 허용 것 도 중요 영상 데이터 를 암호 화 해 도난 물리 적 인 공격 대비 해야 한다 저장 된 영상 재생 후 화면 스마트폰 카메라 로 재 촬영 해 유출 것 막 으려면 영상 재 생시 워터 마크 를 삽입 방안 도 고려 해야 한다',
#  '인공지능 스타트업 업 스테이지 카카오톡 아 숙업 이미지 생성 모델 업 스케치 를 기반 으로 이미지 생성 기능 추가 다고 일 밝혔 선착순 천 명 대상 으로 베타 서비스 를 오픈 다아 숙업 이미지 생성 기능 원 이미지 를 만들 어 주 그려 줘 기능 얼굴 이미지 를 바탕 으로 이미지 를 더 젊 게 혹은 더 멋지 게 바꿔 주 프로필 기능 두 가지 이미지 생성 기능 활용 기 위해서 아 숙업 채팅 창 업 스케치 베타 신청 입력 거나 단 버튼 눌러 이미지 생성 베타 이용 신청 약관 동의 를 면 된다 베타 서비스 기간 선착순 천 명 이미지 생성 기능 자유 롭 게 활용 도록 고 향후 이용자 를 점차 확대 예정 그려 줘 기능 사용 자 원 이미지 대한 설명 이후 그려 줘 를 입력 면 원 이미지 를 생성 기능 예 를 면 밤하늘 오로라 그려 줘 를 입력 면 멋진 오로라 이미지 를 얻 프로필 기능 인물 얼굴 중심 된 사진 아 숙업 전송 고 자신 기호 맞 옵션 선택 면 사진 수정 해 주 기능 사진 전송 면 아 숙업 이미지 로 새로운 이미지 를 생성 해드릴까요 라는 메시지 후 멋있 게 그려 줘 젊 게 그려 줘 옵션 버튼 성별 따라 제공 한다 이미지 생성 위한 그려 줘 기능 프로필 기능 활용 시 크 레딧 소진 한다 즉 현재 채널 친구 제공 되 하루 번 무료 크 레딧 으로 최대 개 이미지 를 만들 어 낼 김성훈 업 스테이지 대표 아 숙업 이미지 생성 기능 추가 이용자 원 이미지 를 편리 게 얻 도록 편익 확대 다며 현재 선착순 천 명 우선 기능 제공 되 지만 점차 인원 늘릴 계획 으로 달 도 안 되 시간 동안 만 유저 라는 엄청난 관심 성원 보답 기 위해 차별 화 된 경험 제공 도록 최선 것 라고 밝혔',
#  '시프 티 올해 창업 년차 기업 으로 동명 인력 관리 솔루션 시프 티 를 주요 제품 으로 국내 인력 관리 근태 관리 업계 에서 탄탄 실적 쌓 아 왔 창업 년차 인 년 이미 흑자 전환 성공 기업 시프 티 도입 으로 근무 일정 휴가 출퇴근 기록 급여 정산 전자 계약 전자 결재 메시지 오픈 사내 연동 모두 가능 시프 티 같 외 내부 적 인 요인 성장 발판 으로 삼 아 년 연속 으로 흑자 영업 이익 성장 어 오 고 또 시 프티 국내 기업 간 협업 도 팔 걷 어 부쳤 시프 티 와 사업 적 으로 시너지 를 낼 기업 대상 으로 전략 적 으로 투자 한다는 방침 이미 개사 투자 완료 되 었 고 월 중 으로 개사 대한 추가 투자 마무리 될 예정 다시 프티 올해 도 인력 관리 업계 대표 솔루션 위치 를 더욱 공고히 고 통합 인력 관리 필요 국내외 기업 고객 적극 적 으로 유치 해 올 해도 안정 적 으로 성장세 를 어 간다는 계획 다시 프티 신승원 대표 올해 로 창업 년 넘어가 년 만 투자 를 받 회사 에서 자체 이익 으로 투자 를 회사 된 것 감개무량 다고 말 며 시프 티 꾸준 성장 더불 어 앞 으로 도 국내 생태 계 더욱 활성 화 될 도록 전략 적 투자 협력 적극 적 으로 어 갈 예정 라고 밝혔 디지털 데일리 이상일 통합 인력 관리 솔루션 시프 티 대표 신승원 작년 대비 매출 영업 이익 성장 기록 며 실적 성장세 를 어 고 다고 밝혔 시프 티 년 총 매출 억 원 총 영업 이익 억 원',
#  '삼성 국내 최초 로 소프트웨어 프로세스 품질 인증 인증 최고 등급 인 등급 획득 다고 일 밝혔 인증 소프트웨어 진흥 법 따라 기업 프로세스 품질 역량 수준 정보 통신 산업 진 흥원 종합 심사 해 등급 부여 인증 제도 제도 기업 프로세스 품질 향상 신뢰 성 확보 를 목적 으로 년 부터 시행 됐으며 등급 획득 기업 삼 성가 유일 다고 회사 측 전했 등급 프로젝트 관리 개발 지원 영역 기준 만족 면 받 고 등급 여기 조직 관리 와 프로세스 개선 영역 까지 인정받 아야 한다 등급 프로젝트 차원 에서 등급 조직 차원 에서 품질 역량 수준 인정 된 것 삼성 지난 년 인증 취득 후 지속 적 인 품질 역량 개선 통해 올해 최고 등급 인 등급 획득 이외 도 삼성 글로벌 기준 품질 경영 시스템 정보 보호 경영 시스템 다양 국제 인증 확보 삼성 앞 으로 도 프로세스 방법 론 시스템 기반 으로 품질 역량 높이 기 위해 지속 노력 계획 김종필 삼성 개발 센터 장 최고 등급 인증 획득 으로 소프트웨어 프로세스 품질 역량 수준 인정받 아 고객 신뢰 를 층 높이 게 됐 다며 삼성 클라우드 플랫폼 소프트웨어 프로세스 품질 역량 바탕 으로 고객 비즈니스 가치 를 높일 도록 최상 서비스 품질 제공 힘쓰 겠 다고 밝혔',
#  '웹 환경 발전 으로 대부분 서비스 시스템 확장 성 유연 성 독립성 제공 레 스풀 방식 채택 고 클라우드 환경 에서 기반 서비스 구축 일반 화 되 면서 수많 간 연계 통합 관리 를 위한 솔루션 관한 관심 높 아 지 고 다는 클라우드 기반 시스템 간 연계 편의 성 목적 으로 개발 되 어 증명서 데이터 유통 플랫 폼 외부 기관 데이터 연계 많 시스템 다양 를 제공 거래 문서 플랫 폼 기반 차세대 프로젝트 다양 플랫 폼 기반 시스템 적용 가능 코리아 엑스 퍼트 안정 성 특별히 강조 며 출시 전 부터 실 프로젝트 에서 개발 되 고 검증 된 제품 라고 설명 공공 기관 문서 유통 시스템 구축 사업 에서 문서 발급 수취 기관 에이전트 방식 연계 변환 솔루션 블록체인 솔루션 백 앤드 연계 서비스 통제 모니터링 통합 관리 부분 적용 되 어 성공 적 인 시스템 구축 해 운영 고 다고 밝혔 다는 사용 요청 키 발급 테스트 배포 모니터링 통합 메트 릭 수집 분석 대시보드 기능 제공 모듈 환경 설정 인증 처리 부하 통제 알림 보안 암호 화 시스템 모니터링 관리 기능 으로 구성 된 모듈 모듈 로 구성 되 어 클라우드 환경 온 프라 미스 환경 모두 지원 아키텍처 를 제공 것 물론 고 폐쇄 형 네트워크 대한 해결책 으로 용 모듈 제공 고 또한 코리아 엑스 퍼트 보유 의사 결정 시스템 블록체인 인증 솔루션 연계 해 레스 트 기반 으로 쉽 게 접근 패키지 를 제공 개발 편의 성 향상 크 게 기여 한다 코리아 엑스 퍼트 사용자 포털 기능 게이트웨이 처리 성능 고도 화 시장 환경 맞춘 지속 적 인 업그레이드 를 위한 본 솔루션 고도 화 연구 개발 진행 고 디지털 데일리 이상일 코리아 엑스 퍼트 대표 유 인지 지난 월 클라우드 온 프라 미스 환경 에서 손쉬운 연계 를 지원 게이트웨이 솔루션 출시 다고 밝혔 다는 프론트 앤드 와 백 앤드 간 호출 관련 된 작업 쉽 게 등록 처리 고 인증 매시업 오류 처리 모니터링 부하 분산 통제 를 관리 게 해 주 솔루션 으로 연계 시스템 개발 필수 적',
#  '토스 플레이스 애플 페이 결제 를 지원 기 위해 국제 결제 표준 규격 인 컨 택트 리스비 접촉 결제 서비스 마지막 단계 인 국내 보안 인증 이달 안 받 예정 컨 택트 리스 인증 카드 결제 구조 를 정하 글로벌 결제 표준 기술 최근 국내 상륙 애플 페이 를 오프라인 에서 이용 기 위해서 컨 택트 리스 인증 받 아야 한다 컨 택트 리스 결제 단말기 인증 비자 와 마스터 카드 결제 네트워크 카드 사 인증 국내 보안 인증 순 으로 이뤄진 현재 토스 플레이스 국내 보안 인증 밟 고 보안 인증 까지 완료 되 면 토스 플레이스 스마트 결제 기기 토스 프론트 집적회로 스마트카드 칩 단말기 접촉 방식 뿐 아니 라 애플 페이 근거리 무선 통신 삼성 페이 마그네 틱 보안 전송 기반 비 접촉 결제 방식 모두 지원 게 된다 최지은 토스 플레이스 대표 애플 페이 대한 관심 높 아 지 면서 별도 애플 페이 결제 단말기 를 구매 려는 소 상공 인 사장 님 도 토스 프론트 올인원 결제 단말기 로 매장 내 몇 개 단말기 를 설치 지 않 아도 일반 신용 카드 간편 결제 애플 페이 결제 모두 가능 다면서 토스 플레이스 사장 님 사업 파트너 로서 간편 함 보안 갖춘 토스 프론트 로 결제 편의 성 극대 화 겠 다고 밝혔 디지털 데일리 이상일 토스 플레이스 대표 최지은 이번 달 안 으로 국내 인증 마무리 고 애플 페이 결제 를 지원 한다고 일 밝혔 로써 토스 플레이스 결제 단말기 토스 프론트 일반 신용카드 네이버 페이 간편 결제 삼성 페이 애플 페이 모두 지원 올인원 결제 단말기 로 자리매김 전망',
#  '스틸 이번 프로젝트 로 기존 시스템 인 최신 버전 인 로 업그레이드 를 통해 데이터 기반 실시간 의사 결정 지원 자원 관리 최적화 기술 지원 종료 정책 대응 비즈니스 경쟁력 한층 강화 게 됐 우선 신규 구축 시스템 인 메모리 기반 뷰 기능 적용 돼 대용량 데이터 실시간 분석 자료 활용 가능 해졌 이전 버전 에서 데이터 추출 가공 별도 영역 에서 처리 돼 데이터 분석 속도 성능 제약 었 또한 원가 재무 영업 구매 인사 애플리케이션 최적화 를 통해 업무 시스템 처리 속도 를 높이 고 기존 오라클 를 로 전환 며 데이터 용량 약 수준 까지 압축 업무 생산 성 운영 효율 성 크 게 향상 시켰 와 함께 버전 기술 지원 종료 앞서 컨버전 완료 해 안정 적 인 차세대 시스템 운영 기반 마련 코오롱 베 니트 와 프로젝트 기간 동안 총 차례 걸친 대 규모 테스트로 사전 검증 마치 고 시스템 다운타임 시간 이내 컨버전 완료 데 성공 어 달 여 간 안정 화 지원 통해 시스템 완성도 를 더 전선규 코오롱 베 니트 상무 새롭 게 구축 차세대 를 기반 으로 스틸 디지털 혁신 더욱 가속 화 될 것 라며 다양 레퍼런스 와 검증 된 기술력 바탕 으로 국내 기업 도입 적극 지원 계획 라고 말 디지털 데일리 이상일 코오롱 베 니트 대표 강이구 그룹 서비스 기업 인 대표 이상준 와 공동 추진 스틸 컨버전 프로젝트 를 성공 적 으로 완료 다고 일 밝혔',
#  '인증 소프트웨어 진흥 법 의거 기업 프로세스 품질 역량 수준 정보 통신 산업 진 흥원 종합 심사 해 등급 부여 인증 제도 제도 기업 프로세스 품질 향상 신뢰 성 확보 를 목적 으로 년 부터 시행 되 었 으며 최고 등급 등급 획득 기업 삼 성가 유일 프로세스 품질 높 다는 것 개발 착수 에서부터 완성 이르 전 프로세스 일관 되 것 물론 지속 적 으로 개선 돼 고객 더 높 품질 서비스 를 제공 다는 의미 등급 프로젝트 관리 개발 지원 영역 기준 만족 면 받 고 등급 여기 조직 관리 와 프로세스 개선 영역 까지 인정받 아야 한다 등급 프로젝트 차원 에서 등급 조직 차원 에서 품질 역량 수준 인정 된 것 삼성 지난 년 인증 취득 후 지속 적 인 품질 역량 개선 통해 올해 최고 등급 인 등급 획득 이외 도 삼성 글로벌 기준 품질 경영 시스템 정보 보호 경영 시스템 다양 국제 인증 확보 삼성 앞 으로 도 프로세스 방법 론 시스템 기반 으로 품질 역량 높이 기 위해 지속 노력 계획 삼성 김종필 개발 센터 장부 사장 최고 등급 인증 획득 으로 소프트웨어 프로세스 품질 역량 수준 인정받 아 고객 신뢰 를 층 높이 게 됐 다며 삼성 클라우드 플랫폼 소프트웨어 프로세스 품질 역량 바탕 으로 고객 비즈니스 가치 를 높일 도록 최상 서비스 품질 제공 힘쓰 겠 다고 밝혔 디지털 데일리 이상일 삼 성가 국내 최초 로 소프트웨어 프로세스 품질 인증 인증 최고 등급 등급 획득',
#  '코로나 이후 재택 원격 근무 환경 확대 되 면서 메일 업무 협업 위한 커뮤니케이션 툴 사용 늘어남 따라 내부 정보 유출 산업 기밀 유출 사례 증가 고 으며 다양 유형 부정행위 잇따라 발생 고 이러 리스크 기업 평판 관리 와 지속 가능 경영 치명 적 인 영향 미치 기 내부 감사 체계 를 통한 규정 강화 관리 대한 중요 성 강조 되 고 지만 기업 내 방대 데이터 에서 부정행위 대한 이상 징후 를 포착 기 위해 상시 감사 를 것 막대 시간 인력 투자 필요 적시 이상 징후 를 파악 고 방지 효율 적 인 대책 마련 최우선 과제 로 떠오르 면서 관련 솔루션 주목 받 고 프론 테 오 코리아 이러 업무 환경 변화 대응 기 위해 년 전 출시 메일 감사 시스템 고도 화 해 커뮤니케이션 협업 툴 감사 솔루션 키 빗 아이 를 개발 솔루션 업무 시 가장 많이 사용 메일 감사 물론 국내 에서 사용 되 다양 협업 툴 상시 적 으로 조사 감사 여 부정행위 를 사전 발견 고 방지 해 준다 솔루션 프론 테 오 연구 팀 자체 개발 사람 판단 능력 시각 적 직관 성 그대로 재현 새로운 알고리즘 탑재 알고리즘 으로 인해 전체 데이터 중 만 열 람 해도 감사 대상 대한 데이터 추출률 달해 기존 대비 분석 정확도 를 크 게 높였 정창 일 프론 테 오 코리아 대표 업무 환경 급격 변화 로 데이터 양 종류 도 많 아 지 고 부정행위 형태 도 다양 해 지 고 어 효율 적 인 관리 더욱 중요 시 되 고 다며 자연어 처리 기술 강점 으로 상시 감사 업무 효율 화 를 지원 여 부정 비리 대한 조기 발견 예방 기여 것 라고 말 디지털 데일리 이상일 프론 테 오 코리아 업무 커뮤니케이션 협업 툴 상시 조사 감사 솔루션 키 빗 아이 를 출시 다고 일 밝혔',
#  '디지털 데일리 이상일 건설 전사 자원 관리 를 중심 으로 성장 해 온 굿 센 기업 환경 사회 지배 구조 경영 본격 화 되 고 가운데 기업 디지털 경영 파트너 로서 역할 나선다 를 기반 으로 새로운 사업 축인 개별 내부 회계 시스템 구축 통해 기업 경영 위한 내부 통제 시장 공략 나서 겠 다는 전략 굿 센 박연정 대표 경영 관리 도구 로서 역할 부상 고 고 내부 통제 역시 경영 관리 툴 로서 관리 필요 상황 굿 센 기업 경영 의사 결정 합리 적 으로 지원 해 주 툴 제공 파트너 로서 기업 미래 경영 동반자 될 것 라고 밝혔 기업 어 선언 적 목표 아니 라 생존 위한 도구 로 평가 되 고 회사 지배 구조 오너 리스크 회사 존폐 여부 까지 가져올 정도 로 사회 성숙 돼 기 소비자 심리 도 선한 선 영향력 가진 기업 제품 서비스 를 선호 경향 뚜렷 해 지 고 결국 기업 경영 를 위한 내부 통제 단순히 법 규제 대응 컴플라이언스 이슈 아니 라 생존 직결 되 문제 되 고 다양 리스크 대응 위해 를 활용 해 경영 거버넌스 대응 기 위한 사전 사전 모니터링 도구 와 정보 를 줄 솔루션 필요 다는 것 대응 기 위해 굿 센 현재 와 내부 회계 시스템 두 축 으로 사업 전개 고 기업 디지털 전환 어 다시 중요 성 부각 되 고 와 함께 경영 어 필수 로 도입 돼야 내부 회계 시스템 융합 해 기업 지속 가능 경영 위한 지원 나설 것 란 설명 굿 센 개별 내부 회계 시스템 개 고 객사 구축 운영 지원 고 다양 에서 연동 지원 해 기업 내부 통제 강화 기여 고 박연정 대표 자체 조사 결과 약 시장 선점 고 다고 본다 내부 회계 연결 회계 지배 회사 중심 으로 구축 해야 해 글로벌 와의 연동 중요 에서 데이터 를 가져가 야 를 연동 해 샘플링 실적 데이터 매칭 고도 화 기술 보유 고 다고 설명 최근 기업 잦 횡령 사건 으로 내부 통제 감사 제도 필요 성 층 강조 되 고 다만 중소기업 바뀐 법 따르 기 엔 운영 부담 커진다는 의견 억 원 미만 자산 기업 경우 내부 회계 관리 제도 외부 감사 면제 된 상황 다만 기업 연결 회계 도입 속도 를 내 고 굿 센 연결 법인 대한 내부 통제 시장 확대 맞춰 그룹 삼천리 고객 확대 한편 억 원 미만 자산 기업 대상 으로 내부 통제 툴 저렴 게 이용 가능 개발 통해 대응 한다는 계획 박연정 대표 굿 센 구축 평균 년 이상 내부 회계 관리 제도 를 경험 해 연결 내부 회계 제도 이해 와 경험 뛰어나 또 연결 내부 회계 시스템 그룹 타 법인 같이 운영 해야 해 법인 별 네트워크 환경 보안 체계 싱글 사 인온 서로 다른 환경 통합 운영 관리 역량 필요 다며 굿 센 그룹 사 인 클라우드 부분 클로 잇과 협력 그룹 사 역량 집결 해 기업 내부 통제 고도 화 대응 고 다고 설명 또 박 대표 아이 티센 그룹 전환 통한 새로운 도약 라는 비전 따라 굿 센 제품 서비스 중 킬러 서비스 를 발굴 를 모듈 화 해 로 전환 그림 그리 고 제품 전체 를 로 전환 기 보 다는 기업 필요 기능 로 만들 어 다양 파트너 생태 계 에서 역할 것 라고 강조 한편 박연정 대표 한국 소프트웨어 산업 협회 위원회 초대 위원장 맡 고 협회 차원 에서 기업 경영 실태 조사 나선 상황 으로 기업 경영 구체 적 으로 협력 업체 평가 생태 계 부분 에서 무엇 준비 해야 는지 를 회원 사 제공 것 목표 다박 대표 굿 센 역시 를 운영 해 와 간 상호 관계 를 연구 중 며 향후 고객 사 회계 법인 협업 해 형 솔루션 출시 예정 라고 밝혔 현재 코 넥스 상장 돼 굿 센 코스닥 이전 상장 준비 중 박 대표 재무 적 도전 과제 이미 달성 고 우리 기업 가치 를 높 게 판단 받 것 중요 다고 본다 사업 우리 만 색깔 어떻게 입힐 것 인가 고민 중 내부 적 으로 굿 센 직원 새로운 기술 트렌드 시장 변화 기민 게 반응 면서 자체 적 인 디지털 전환 이뤄지게 것 도 목표 아이 티센 그룹 방향 성 맞 게 성공 적 으로 전이 고자 한다고 강조']

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

# %%
#- 훈련 데이터와 테스트 데이터를 분리합니다.
X_train, X_test, y_train, y_test = train_test_split(text_data, df['code1'], random_state = 0)

# %%
print('훈련용 뉴스 기사의 개수 :', len(X_train))
print('테스트용 뉴스 기사의 개수 : ', len(X_test))
print('훈련용 레이블의 개수 : ', len(y_train))
print('테스트용 레이블의 개수 : ', len(y_test))
# Out:
# 훈련용 뉴스 기사의 개수 : 43
# 테스트용 뉴스 기사의 개수 :  15
# 훈련용 레이블의 개수 :  43
# 테스트용 레이블의 개수 :  15

# %%
#- 단어의 수를 카운트하는 사이킷런의 카운트벡터라이저입니다.
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)

#- 카운트벡터라이저의 결과로부터 TF-IDF 결과를 얻습니다.
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

#- 나이브 베이즈 분류기를 수행합니다.
#- X_train은 TF-IDF 벡터, y_train은 레이블입니다.
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
def tfidf_vectorizer(data):
    data_counts = count_vect.transform(data)
    data_tfidf = tfidf_transformer.transform(data_counts)
    return data_tfidf

# %%
new_sent = preprocessing(["민주당 일각에서 법사위의 체계·자구 심사 기능을 없애야 한다는 \
                           주장이 나오는 데 대해 “체계·자구 심사가 법안 지연의 수단으로 \
                          쓰이는 것은 바람직하지 않다”면서도 “국회를 통과하는 법안 중 위헌\
                          법률이 1년에 10건 넘게 나온다. 그런데 체계·자구 심사까지 없애면 매우 위험하다”고 반박했다."])
print(clf.predict(tfidf_vectorizer(new_sent)))
# Out:
# ['IT/과학']

# %%
new_sent = preprocessing(["인도 로맨틱 코미디 영화 <까립까립 싱글>(2017)을 봤을 때 나는 두 눈을 의심했다. \
                          저 사람이 남자 주인공이라고? 노안에 가까운 이목구비와 기름때로 뭉친 파마머리와, \
                          대충 툭툭 던지는 말투 등 전혀 로맨틱하지 않은 외모였다. 반감이 일면서 \
                          ‘난 외모지상주의자가 아니다’라고 자부했던 나에 대해 회의가 들었다.\
                           티브이를 꺼버릴까? 다른 걸 볼까? 그런데, 이상하다. 왜 이렇게 매력 있지? 개구리와\
                            같이 툭 불거진 눈망울 안에는 어떤 인도 배우에게서도 느끼지 못한 \
                            부드러움과 선량함, 무엇보다 슬픔이 있었다. 2시간 뒤 영화가 끝나고 나는 완전히 이 배우에게 빠졌다"])
print(clf.predict(tfidf_vectorizer(new_sent)))
# Out:
# ['생활/문화']

# %%
new_sent = preprocessing(["20분기 연속으로 적자에 시달리는 LG전자가 브랜드 이름부터 성능, 디자인까지 대대적인 변화를 \
                          적용한 LG 벨벳은 등장 전부터 온라인 커뮤니티를 뜨겁게 달궜다. 사용자들은 “디자인이 예쁘다”, \
                          “슬림하다”는 반응을 보이며 LG 벨벳에 대한 기대감을 드러냈다."])
print(clf.predict(tfidf_vectorizer(new_sent)))
# Out:
# ['IT/과학']

# %%
y_pred = clf.predict(tfidf_vectorizer(X_test))
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        IT/과학       0.44      1.00      0.62         4
#           사회       0.75      0.75      0.75         4
#        생활/문화       1.00      0.29      0.44         7
#
#     accuracy                           0.60        15
#    macro avg       0.73      0.68      0.60        15
# weighted avg       0.79      0.60      0.57        15
